# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from fbprophet import Prophet
from sklearn.metrics import mean_squared_error, mean_absolute_error
plt.style.use('seaborn-whitegrid') # For plots
import datetime

from sklearn.preprocessing import MinMaxScaler
# Out:
# Importing plotly failed. Interactive plots will not work.

# %% [markdown]
# # Prepare data

# %%
def format_data(df):
    
    # index is date
    df = df.set_index("Date")
    df.index = pd.to_datetime(df.index)
    
    # add missing date
    idx = pd.date_range(start = min(df.index), end = max(df.index))
    df = df.reindex(idx)
    
    # fill na with the previous value
    df = df.fillna(1) # 0 might makes more sense
    
    # replace estimated_fire_area with log
    df = df.rename(columns = {"Estimated_fire_area": "fire"})
    df["fire_log"] = np.log(df["fire"])
    
    # remove difference
    df["fire_diff"] = (df["fire"] - df["fire"].shift()).fillna(0)
    
    # create feature
    df['date'] = df.index
    df['dayofweek'] = df['date'].dt.dayofweek
    df['quarter'] = df['date'].dt.quarter
    df['month'] = df['date'].dt.month
    df['year'] = df['date'].dt.year
    df['dayofyear'] = df['date'].dt.dayofyear
    df['dayofmonth'] = df['date'].dt.day
    df['weekofyear'] = df['date'].dt.weekofyear

    return df

# %%
nsw = pd.read_csv("../data/regions/NSW.csv")
nsw = format_data(nsw)
nsw.head()
# Out:
# <ipython-input-62-2ba4bf4088cd>:29: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   df['weekofyear'] = df['date'].dt.weekofyear
#             Precipitation_max  RelativeHumidity_max  SoilWaterContent_max  \
# 2005-01-04          22.842566             90.332771              0.444927
# 2005-01-05           7.657155             88.623436              0.442955
# 2005-01-06          27.616505             92.850960              0.431879
# 2005-01-07           3.839235             79.103134              0.418513
# 2005-01-08           2.866673             83.001541              0.413370
#
#             SolarRadiation_max  Temperature_max  WindSpeed_max  \
# 2005-01-04           33.214062        28.945488       7.364222
# 2005-01-05           33.554867        29.510120       7.091141
# 2005-01-06           34.075787        26.982698       9.905821
# 2005-01-07           34.019218        24.752069      10.446799
# 2005-01-08           33.265091        26.472469       6.671862
#
#             Precipitation_mean  RelativeHumidity_mean  SoilWaterContent_mean  \
# 2005-01-04            2.808620              57.095628               0.214293
# 2005-01-05            0.157935              47.170735               0.203951
# 2005-01-06            0.434833              39.874638               0.193668
# 2005-01-07            0.064224              39.279410               0.183778
# 2005-01-08            0.203352              42.400824               0.175935
#
#             SolarRadiation_mean  ...  fire_log  fire_diff       date  \
# 2005-01-04            22.617291  ...  2.161022    0.00000 2005-01-04
# 2005-01-05            28.076835  ...  2.810080    7.93125 2005-01-05
# 2005-01-06            30.561703  ...  1.708378  -11.09125 2005-01-06
# 2005-01-07            32.143718  ...  1.834819    0.74400 2005-01-07
# 2005-01-08            29.347715  ...  1.686399   -0.86400 2005-01-08
#
#             dayofweek  quarter month  year  dayofyear  dayofmonth  weekofyear
# 2005-01-04          1        1     1  2005          4           4           1
# 2005-01-05          2        1     1  2005          5           5           1
# 2005-01-06          3        1     1  2005          6           6           1
# 2005-01-07          4        1     1  2005          7           7           1
# 2005-01-08          5        1     1  2005          8           8           1
#
# [5 rows x 23 columns]

# %%
sns.pairplot(nsw.dropna(),
             hue='dayofweek',
             x_vars=['dayofweek',
                     'year','weekofyear'],
             y_vars='fire',
             height=5,
             plot_kws={'alpha':0.5, 'linewidth':0}
            )
plt.suptitle('Estimated wild fire by Hour, Day of Week, Year and Week of Year')
plt.show()

# %%
nsw[nsw.index <= '2022-1-1'].plot(y = "fire_log", figsize = (15, 5), style = ".")
plt.show()

# %%
ts = nsw[["fire_log"]]
ts = ts.reset_index().rename(columns = {"index": "ds", "fire_log": "y"})
ts
# Out:
#              ds         y
# 0    2005-01-04  2.161022
# 1    2005-01-05  2.810080
# 2    2005-01-06  1.708378
# 3    2005-01-07  1.834819
# 4    2005-01-08  1.686399
# ...         ...       ...
# 5775 2020-10-27  0.190620
# 5776 2020-10-28  1.098612
# 5777 2020-10-29  0.000000
# 5778 2020-10-30  0.277632
# 5779 2020-10-31  3.009438
#
# [5780 rows x 2 columns]

# %%
split_date = "2020-03-01"
ts_train = ts.loc[ts["ds"] < split_date].copy()
ts_test = ts.loc[ts["ds"] >= split_date].copy()

# %%
ts_test.set_index("ds") \
    .rename(columns={'y': 'test'}) \
    .join(ts_train.set_index("ds").rename(columns={'y': 'train'}), how='outer') \
    .plot(figsize=(15,5), title='NSW', style='.')
plt.show()

# %% [markdown]
# # Prophet

# %%
m = Prophet()
m.fit(ts_train)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
forcast = m.predict(ts_test)

# %%
f, ax = plt.subplots(1)
f.set_figheight(5)
f.set_figwidth(15)
fig = m.plot(forcast, ax=ax)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
fig = m.plot_components(forcast)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
f, ax = plt.subplots(1)
f.set_figheight(5)
f.set_figwidth(15)
ax.scatter(ts_test["ds"], ts_test['y'], color='r')
fig = m.plot(forcast, ax=ax)

# %%
f, ax = plt.subplots(1)
f.set_figheight(5)
f.set_figwidth(15)
ax.scatter(pd.to_datetime(ts_test["ds"]), ts_test['y'], color='r')
fig = m.plot(forcast, ax=ax)
ax.set_xbound(lower=datetime.datetime(2017,1,1),
              upper=datetime.datetime(2018,1,1))
ax.set_ylim(0, 5)
plot = plt.suptitle('January 2017 Forecast vs Actuals')

# %%
mse = mean_squared_error(y_true = np.exp(ts_test["y"]), y_pred = np.exp(forcast["yhat"]))
mape = mean_absolute_error(y_true = ts_test["y"], y_pred = forcast["yhat"])
rmse = np.sqrt(mse)

rmse, mape
# Out:
# (61.91075622595063, 2.721882239336217)

# %%
forcast_train = m.predict(ts_train)

# %%
mse = mean_squared_error(y_true = np.exp(ts_train["y"]), y_pred = np.exp(forcast_train["yhat"]))
mape = mean_absolute_error(y_true = ts_train["y"], y_pred = forcast_train["yhat"])
rmse = np.sqrt(mse)

rmse, mape
# Out:
# (177.1085502495032, 1.1789506392791564)

# %%
f, ax = plt.subplots(1)
f.set_figheight(5)
f.set_figwidth(15)
ax.scatter(ts_train["ds"], ts_train['y'], color='r')
fig = m.plot(forcast_train, ax=ax)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
ts_future = m.make_future_dataframe(periods = 1750)
ts_future.tail()
# Out:
#              ds
# 5911 2021-03-12
# 5912 2021-03-13
# 5913 2021-03-14
# 5914 2021-03-15
# 5915 2021-03-16

# %%
future = m.predict(ts_future)

f, ax = plt.subplots(1)
f.set_figheight(5)
f.set_figwidth(15)
ax.scatter(ts["ds"], ts['y'], color='r')
fig = m.plot(future, ax=ax)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %% [markdown]
# # SARIMAX

# %%
fire = pd.read_csv("../data/Historical_Wildfire_fill0.csv")
fire = fire.rename(columns = {'Date': 'date', 'Estimated_fire_area': 'fire', 'Region': 'region'})
fire['date'] = pd.to_datetime(fire['date'])
fire = fire.drop(['Mean_estimated_fire_brightness', 'Mean_estimated_fire_radiative_power', 'Mean_confidence'], axis = 1)
fire = fire.set_index('date')

# %%
nsw = fire[fire['region'] == 'NSW'].drop('region', axis = 1)

# log scale
nsw['fire'] = nsw['fire'].replace(0, 1) # na is 1 instead of 0 for log
nsw['fire_log'] = np.log(nsw['fire'])

# consider only < 2019-07-01
nsw = nsw.loc[nsw.index < "2019-07-01"]

nsw.tail()
# Out:
#                  fire  fire_log
# date
# 2019-06-26  14.533846  2.676480
# 2019-06-27  16.265833  2.789067
# 2019-06-28  27.375000  3.309630
# 2019-06-29   3.200000  1.163151
# 2019-06-30   6.630000  1.891605

# %%
nsw.plot(y = 'fire_log', style = '.', figsize = (15, 5))

# %%
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from statsmodels.tsa.stattools import adfuller
from tqdm import tqdm_notebook

# %%
data = nsw.copy()

data['log_diff'] = data['fire_log'].diff()
data = data.drop(data.index[0])
data.plot(y = 'log_diff')
plt.show()

data['season'] = data['log_diff'].diff(4)
data = data.drop(data.index[0:4], axis = 0).reset_index(drop=True)
data.plot(y = 'season')
plt.show()

# %%
ad_fuller_result = adfuller(data['season'])
print(f'ADF Statistic: {ad_fuller_result[0]}')
print(f'p-value: {ad_fuller_result[1]}')
# Out:
# ADF Statistic: -25.805329587758884
# p-value: 0.0

# %%
plot_pacf(data['season'])
plot_acf(data['season'])
plt.show()

# %%
# source: https://github.com/marcopeix/time-series-analysis/blob/master/Advanced%20modelling/SARIMA.ipynb
def optimize_SARIMA(parameters_list, d, D, s, exog):
    """
        Return dataframe with parameters, corresponding AIC and SSE
        
        parameters_list - list with (p, q, P, Q) tuples
        d - integration order
        D - seasonal integration order
        s - length of season
        exog - the exogenous variable
    """
    
    results = []
    
    for param in tqdm_notebook(parameters_list):
        try: 
            model = SARIMAX(exog, order=(param[0], d, param[1]), seasonal_order=(param[2], D, param[3], s)).fit(disp=-1)
        except:
            continue
            
        aic = model.aic
        results.append([param, aic])
        
    result_df = pd.DataFrame(results)
    result_df.columns = ['(p,q)x(P,Q)', 'AIC']
    #Sort in ascending order, lower AIC is better
    result_df = result_df.sort_values(by='AIC', ascending=True).reset_index(drop=True)
    
    return result_df

# %%
from itertools import product

p = range(0, 4, 1)
d = 1
q = range(0, 4, 1)
P = range(0, 4, 1)
D = 1
Q = range(0, 4, 1)
s = 4

parameters = product(p, q, P, Q)
parameters_list = list(parameters)
print(len(parameters_list))
# Out:
# 256

# %%
result_df = optimize_SARIMA(parameters_list, 1, 1, 4, data['season'])
result_df
# Out:
# <ipython-input-238-814014cf8cec>:15: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for param in tqdm_notebook(parameters_list):
# HBox(children=(FloatProgress(value=0.0, max=256.0), HTML(value='')))
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
