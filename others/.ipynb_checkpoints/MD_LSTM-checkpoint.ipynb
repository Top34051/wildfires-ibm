# %% [markdown]
# # Wildfires Forecasting Model
# ### Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import keras
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.optimizers import Adam

from datetime import date, timedelta, datetime
import itertools


# %matplotlib inline

# %% [markdown]
# ### Loading Data

# %%
data_path = '../data/Nov_10'

df1 = pd.read_csv(f'{data_path}/Historical_Wildfires.csv')
df2 = pd.read_csv(f'{data_path}/HistoricalWeather.csv')
df3 = pd.read_csv(f'{data_path}/HistoricalWeatherForecasts.csv')
df4 = pd.read_csv(f'{data_path}/LandClass.csv')
df5 = pd.read_csv(f'{data_path}/VegetationIndex.csv')

# %%
df1
# Out:
#       Region        Date  Estimated_fire_area  Mean_estimated_fire_brightness  \
# 0        NSW    1/4/2005             8.680000                      312.266667
# 1        NSW    1/5/2005            16.611250                      322.475000
# 2        NSW    1/6/2005             5.520000                      325.266667
# 3        NSW    1/7/2005             6.264000                      313.870000
# 4        NSW    1/8/2005             5.400000                      337.383333
# ...      ...         ...                  ...                             ...
# 26401     WA  10/27/2020            32.970000                      324.068182
# 26402     WA  10/28/2020            20.840625                      314.425000
# 26403     WA  10/29/2020           136.083077                      323.588461
# 26404     WA  10/30/2020            42.397895                      324.205263
# 26405     WA  10/31/2020           107.370851                      330.057447
#
#        Mean_estimated_fire_radiative_power  Mean_confidence  Std_confidence  \
# 0                                42.400000        78.666667        2.886751
# 1                                62.362500        85.500000        8.088793
# 2                                38.400000        78.333333        3.214550
# 3                                33.800000        92.200000        7.529940
# 4                               122.533333        91.000000        7.937254
# ...                                    ...              ...             ...
# 26401                           103.318182        84.363636        5.277741
# 26402                            37.256250        88.312500        8.121730
# 26403                           294.102564        92.974359        8.282789
# 26404                            54.994737        89.631579        8.461107
# 26405                           201.625532        92.978723        7.266628
#
#        Var_confidence  Count Replaced
# 0            8.333333      3        R
# 1           65.428571      8        R
# 2           10.333333      3        R
# 3           56.700000      5        R
# 4           63.000000      3        R
# ...               ...    ...      ...
# 26401       27.854545     11        N
# 26402       65.962500     16        N
# 26403       68.604588     39        N
# 26404       71.590327     38        N
# 26405       52.803885     47        N
#
# [26406 rows x 10 columns]

# %%
df2
# Out:
#               Date Region         Parameter  count()[unit: km^2]      min()  \
# 0       2005-01-01    NSW     Precipitation         8.002343e+05   0.000000
# 1       2005-01-01    NSW  RelativeHumidity         8.002343e+05  13.877194
# 2       2005-01-01    NSW  SoilWaterContent         8.002343e+05   0.002245
# 3       2005-01-01    NSW    SolarRadiation         8.002343e+05  14.515009
# 4       2005-01-01    NSW       Temperature         8.002343e+05  14.485785
# ...            ...    ...               ...                  ...        ...
# 242776  2020-10-31     WA  RelativeHumidity         2.528546e+06   9.272744
# 242777  2020-10-31     WA  SoilWaterContent         2.528546e+06   0.000000
# 242778  2020-10-31     WA    SolarRadiation         2.528546e+06  17.072290
# 242779  2020-10-31     WA       Temperature         2.528546e+06  16.238239
# 242780  2020-10-31     WA         WindSpeed         2.528546e+06   1.704024
#
#             max()     mean()  variance()
# 0        1.836935   0.044274    0.028362
# 1       80.522964  36.355567  253.559937
# 2        0.414305   0.170931    0.007758
# 3       32.169781  26.749389    6.078587
# 4       35.878704  27.341182   18.562212
# ...           ...        ...         ...
# 242776  82.022224  34.193973  309.018764
# 242777   0.285399   0.050737    0.001419
# 242778  29.743744  26.746413    5.986063
# 242779  34.669132  28.090392   15.293953
# 242780   9.031948   4.373947    1.873607
#
# [242781 rows x 8 columns]

# %%
df3
# Out:
#               Date Region         Parameter  Lead time  count()[unit: km^2]  \
# 0       2014-01-01    NSW  RelativeHumidity          5         8.037682e+05
# 1       2014-01-01    NSW    SolarRadiation          5         8.037682e+05
# 2       2014-01-01    NSW       Temperature          5         8.037682e+05
# 3       2014-01-01    NSW         WindSpeed          5         8.037682e+05
# 4       2014-01-01     NT  RelativeHumidity          5         1.349817e+06
# ...            ...    ...               ...        ...                  ...
# 217207  2020-10-31     WA       Temperature         10         2.542548e+06
# 217208  2020-10-31     WA       Temperature         15         2.542548e+06
# 217209  2020-10-31     WA         WindSpeed          5         2.542548e+06
# 217210  2020-10-31     WA         WindSpeed         10         2.542548e+06
# 217211  2020-10-31     WA         WindSpeed         15         2.542548e+06
#
#             min()      max()     mean()  variance()
# 0        7.482927  85.021118  28.223569  353.620815
# 1       24.865765  33.557598  31.647308    2.276068
# 2       21.243755  36.929035  30.893523   17.918553
# 3        1.593531   6.989559   3.958822    1.334834
# 4       14.796251  73.601479  39.799856  189.805002
# ...           ...        ...        ...         ...
# 217207  16.062984  34.801270  26.999880   14.610838
# 217208  12.785835  36.613548  28.529795   32.340741
# 217209   1.311029   9.138333   5.245600    2.626650
# 217210   0.365395  10.549594   5.451390    2.232168
# 217211   0.446725  10.257668   4.828480    2.859307
#
# [217212 rows x 9 columns]

# %%
df4
# Out:
#   Region  Shrubs  Herbaceous vegetation  \
# 0    NSW     6.2                   43.6
# 1     NT    18.1                   48.9
# 2     QL     9.5                   45.3
# 3     SA    24.1                   54.8
# 4     TA     0.7                   23.8
# 5     WA    31.3                   43.5
# 6     VI     1.4                   35.0
#
#    Cultivated and managed vegetation/agriculture (cropland)  Urban / built up  \
# 0                                               13.0                      0.3
# 1                                                0.1                      0.0
# 2                                                1.6                      0.1
# 3                                                5.8                      0.1
# 4                                                1.2                      0.2
# 5                                                5.6                      0.0
# 6                                               23.3                      1.0
#
#    Bare / sparse vegetation  Permanent water bodies  Herbaceous wetland  \
# 0                       0.2                     0.2                 0.1
# 1                       0.4                     0.1                 0.1
# 2                       1.1                     0.1                 0.0
# 3                       4.8                     1.2                 0.1
# 4                       0.1                     1.9                 1.4
# 5                       1.0                     0.4                 0.0
# 6                       0.1                     0.6                 0.3
#
#    Closed forest, evergreen, broad leaf  Closed forest, deciduous broad leaf  \
# 0                                  14.7                                  6.8
# 1                                   1.0                                  7.7
# 2                                   5.3                                 13.3
# 3                                   0.3                                  1.3
# 4                                  50.1                                  0.6
# 5                                   1.2                                  2.4
# 6                                  23.9                                  3.8
#
#    Closed forest, unknown  Open forest, evergreen broad leaf  \
# 0                     0.3                                0.5
# 1                     0.1                                0.1
# 2                     0.3                                0.1
# 3                     0.1                                0.1
# 4                     1.1                                7.2
# 5                     0.2                                0.1
# 6                     0.3                                1.5
#
#    Open forest, deciduous broad leaf  Open forest, unknown definitions  \
# 0                                3.7                              10.3
# 1                               13.6                               9.3
# 2                               12.0                              11.0
# 3                                1.4                               5.3
# 4                                1.5                               7.2
# 5                                4.8                               8.7
# 6                                2.7                               5.2
#
#    Open sea
# 0       0.1
# 1       0.5
# 2       0.3
# 3       0.6
# 4       3.0
# 5       0.8
# 6       0.9

# %%
df5
# Out:
#      Region       Date  Vegetation_index_mean  Vegetation_index_max  \
# 0       NSW   1/1/2005               0.349202                0.9972
# 1       NSW   2/1/2005               0.357403                0.9772
# 2       NSW   3/1/2005               0.354087                0.9750
# 3       NSW   4/1/2005               0.347242                0.9904
# 4       NSW   5/1/2005               0.345526                0.9972
# ...     ...        ...                    ...                   ...
# 1325     WA   6/1/2020               0.263760                0.9886
# 1326     WA   7/1/2020               0.265321                0.9941
# 1327     WA   8/1/2020               0.255785                0.9692
# 1328     WA   9/1/2020               0.234510                0.9849
# 1329     WA  10/1/2020               0.213640                0.9782
#
#       Vegetation_index_min  Vegetation_index_std  Vegetation_index_variance
# 0                     -0.2              0.204862                   0.041968
# 1                     -0.2              0.208673                   0.043544
# 2                     -0.2              0.209450                   0.043869
# 3                     -0.2              0.207307                   0.042976
# 4                     -0.2              0.202858                   0.041151
# ...                    ...                   ...                        ...
# 1325                  -0.2              0.129103                   0.016667
# 1326                  -0.2              0.148663                   0.022101
# 1327                  -0.2              0.155347                   0.024133
# 1328                  -0.2              0.126898                   0.016103
# 1329                  -0.2              0.099860                   0.009972
#
# [1330 rows x 7 columns]

# %% [markdown]
# ### Format each dataframe to Day/Region based

# %%
def trans_Hist_Weather(df) :
    
    df = df.rename(columns = {'count()[unit: km^2]' : 'Area', 'min()' : 'Min',
                               'max()' : 'Max', 'mean()' : 'Mean', 'variance()' : 'Variance'})
    df = df.pivot_table(values=['Min','Max','Mean','Variance'], index=['Date','Region'],
                                      columns=['Parameter'])
    df.reset_index(inplace = True)
    df.columns = [c[0] if c[1] == '' else f'{c[1]}_{c[0]}' for c in df.columns.values]
    df['Date'] = pd.to_datetime(df['Date'])
    
    return df

def trans_Hist_Weather_Forecast(df) :
    
    df = df.rename(columns = {'count()[unit: km^2]' : 'Area', 'min()' : 'Min',
                                   'max()' : 'Max', 'mean()' : 'Mean', 'variance()' : 'Variance'})
    df = df.pivot_table(values = ['Min','Max','Mean','Variance'], index = ['Date','Region'],
                                 columns = ['Parameter', 'Lead time'])
    df.reset_index(inplace = True)
    df.columns = [c[0] if c[1] == '' else f'{c[1]}_{c[0]}_{c[2]}' for c in df.columns.values]
    df.fillna(0, inplace=True) #missing 
    df['Date'] = pd.to_datetime(df['Date'])
    
    return df

# %%
df2 = trans_Hist_Weather(df2)
df3 = trans_Hist_Weather_Forecast(df3)

# %% [markdown]
# ### Finding missing date and time

# %%
def find_missing_date(df, start_date = (2005,1,1), end_date = (2020,10,31), 
                      region = ['NSW', 'NT', 'QL', 'SA', 'TA', 'VI', 'WA'], date_col = 'Date') :
    
    df['Date'] = pd.to_datetime(df['Date'])
    start_date = date(start_date[0], start_date[1], start_date[2])
    end_date = date(end_date[0], end_date[1], end_date[2])
    total_date_set = set([start_date + timedelta(x) for x in range((end_date- start_date).days)])
    
    missing = dict()
    for reg in region : 
        df_temp = df[df['Region'] == reg]
        date_list = list(df_temp[date_col])
        date_set = set([ts.date() for ts in date_list])
        
        missing[reg] = total_date_set - date_set
        
    return missing

# %% [markdown]
# ## Experiment #1
# ### Univariate Forecasting
# 1. Try 30d timesteps forecasting
# 2. Lag Time for 30 day
# 3. See Result
# 4. Only NSW Region
# 5. Use Historical Wildfire data only

# %%
#find missing date
find_missing_date(df1, region = ['NSW'])
# Out:
# {'NSW': {datetime.date(2010, 12, 2),
#   datetime.date(2010, 3, 14),
#   datetime.date(2008, 11, 20),
#   datetime.date(2008, 7, 9),
#   datetime.date(2012, 6, 19),
#   datetime.date(2011, 1, 1),
#   datetime.date(2010, 2, 16),
#   datetime.date(2014, 3, 16),
#   datetime.date(2011, 7, 30),
#   datetime.date(2008, 11, 9),
#   datetime.date(2013, 12, 11),
#   datetime.date(2013, 12, 25),
#   datetime.date(2010, 8, 27),
#   datetime.date(2010, 9, 12),
#   datetime.date(2005, 9, 17),
#   datetime.date(2016, 1, 30),
#   datetime.date(2010, 6, 5),
#   datetime.date(2016, 8, 25),
#   datetime.date(2016, 6, 3),
#   datetime.date(2018, 10, 6),
#   datetime.date(2016, 2, 20),
#   datetime.date(2016, 1, 1),
#   datetime.date(2008, 7, 23),
#   datetime.date(2010, 11, 5),
#   datetime.date(2009, 9, 6),
#   datetime.date(2011, 12, 5),
#   datetime.date(2016, 8, 20),
#   datetime.date(2017, 2, 10),
#   datetime.date(2020, 8, 29),
#   datetime.date(2008, 1, 10),
#   datetime.date(2010, 7, 2),
#   datetime.date(2009, 1, 8),
#   datetime.date(2020, 7, 13),
#   datetime.date(2008, 6, 18),
#   datetime.date(2018, 1, 11),
#   datetime.date(2014, 2, 15),
#   datetime.date(2017, 6, 16),
#   datetime.date(2016, 1, 5),
#   datetime.date(2013, 7, 16),
#   datetime.date(2016, 9, 20),
#   datetime.date(2017, 10, 20),
#   datetime.date(2007, 6, 8),
#   datetime.date(2017, 12, 1),
#   datetime.date(2006, 3, 2),
#   datetime.date(2018, 10, 21),
#   datetime.date(2019, 6, 3),
#   datetime.date(2009, 2, 14),
#   datetime.date(2018, 12, 12),
#   datetime.date(2015, 9, 5),
#   datetime.date(2015, 6, 25),
#   datetime.date(2008, 12, 8),
#   datetime.date(2016, 6, 25),
#   datetime.date(2012, 6, 24),
#   datetime.date(2016, 12, 26),
#   datetime.date(2010, 12, 4),
#   datetime.date(2011, 8, 11),
#   datetime.date(2008, 12, 5),
#   datetime.date(2018, 7, 1),
#   datetime.date(2020, 2, 26),
#   datetime.date(2008, 1, 27),
#   datetime.date(2007, 11, 24),
#   datetime.date(2011, 1, 14),
#   datetime.date(2012, 7, 16),
#   datetime.date(2014, 3, 29),
#   datetime.date(2013, 5, 16),
#   datetime.date(2006, 11, 8),
#   datetime.date(2016, 9, 21),
#   datetime.date(2009, 10, 11),
#   datetime.date(2016, 8, 24),
#   datetime.date(2008, 2, 4),
#   datetime.date(2009, 12, 26),
#   datetime.date(2020, 9, 2),
#   datetime.date(2007, 1, 26),
#   datetime.date(2012, 11, 27),
#   datetime.date(2008, 12, 13),
#   datetime.date(2018, 6, 28),
#   datetime.date(2006, 11, 11),
#   datetime.date(2010, 9, 4),
#   datetime.date(2018, 2, 25),
#   datetime.date(2020, 5, 31),
#   datetime.date(2013, 7, 21),
#   datetime.date(2007, 12, 16),
#   datetime.date(2014, 8, 25),
#   datetime.date(2018, 10, 5),
#   datetime.date(2014, 12, 24),
#   datetime.date(2013, 6, 1),
#   datetime.date(2007, 6, 21),
#   datetime.date(2014, 6, 29),
#   datetime.date(2015, 6, 19),
#   datetime.date(2011, 12, 19),
#   datetime.date(2014, 9, 2),
#   datetime.date(2005, 7, 10),
#   datetime.date(2017, 7, 16),
#   datetime.date(2005, 11, 22),
#   datetime.date(2010, 6, 9),
#   datetime.date(2015, 4, 19),
#   datetime.date(2015, 4, 26),
#   datetime.date(2006, 2, 26),
#   datetime.date(2010, 9, 6),
#   datetime.date(2014, 2, 23),
#   datetime.date(2009, 11, 7),
#   datetime.date(2014, 1, 2),
#   datetime.date(2017, 12, 23),
#   datetime.date(2012, 1, 19),
#   datetime.date(2011, 10, 2),
#   datetime.date(2016, 6, 21),
#   datetime.date(2008, 1, 28),
#   datetime.date(2009, 10, 27),
#   datetime.date(2016, 9, 3),
#   datetime.date(2011, 11, 24),
#   datetime.date(2005, 10, 30),
#   datetime.date(2014, 7, 26),
#   datetime.date(2012, 6, 16),
#   datetime.date(2008, 11, 28),
#   datetime.date(2016, 7, 10),
#   datetime.date(2010, 7, 20),
#   datetime.date(2015, 5, 29),
#   datetime.date(2018, 12, 15),
#   datetime.date(2014, 2, 26),
#   datetime.date(2010, 10, 10),
#   datetime.date(2010, 11, 22),
#   datetime.date(2011, 5, 25),
#   datetime.date(2011, 12, 11),
#   datetime.date(2007, 6, 7),
#   datetime.date(2016, 6, 4),
#   datetime.date(2017, 7, 15),
#   datetime.date(2008, 6, 19),
#   datetime.date(2008, 1, 23),
#   datetime.date(2011, 12, 7),
#   datetime.date(2012, 7, 22),
#   datetime.date(2011, 10, 8),
#   datetime.date(2017, 12, 2),
#   datetime.date(2008, 11, 13),
#   datetime.date(2006, 3, 30),
#   datetime.date(2015, 4, 18),
#   datetime.date(2015, 11, 2),
#   datetime.date(2008, 10, 24),
#   datetime.date(2015, 6, 18),
#   datetime.date(2020, 7, 29),
#   datetime.date(2006, 10, 16),
#   datetime.date(2006, 7, 15),
#   datetime.date(2011, 11, 26),
#   datetime.date(2019, 3, 24),
#   datetime.date(2007, 12, 30),
#   datetime.date(2012, 12, 19),
#   datetime.date(2010, 7, 25),
#   datetime.date(2020, 10, 26),
#   datetime.date(2012, 3, 6),
#   datetime.date(2008, 9, 2),
#   datetime.date(2017, 6, 1),
#   datetime.date(2005, 11, 23),
#   datetime.date(2014, 12, 22),
#   datetime.date(2012, 2, 2),
#   datetime.date(2009, 2, 17),
#   datetime.date(2005, 8, 5),
#   datetime.date(2016, 9, 6),
#   datetime.date(2019, 5, 3),
#   datetime.date(2020, 6, 28),
#   datetime.date(2010, 4, 6),
#   datetime.date(2019, 5, 10),
#   datetime.date(2017, 6, 28),
#   datetime.date(2012, 5, 25),
#   datetime.date(2009, 10, 30),
#   datetime.date(2015, 1, 31),
#   datetime.date(2012, 1, 29),
#   datetime.date(2008, 12, 6),
#   datetime.date(2010, 10, 14),
#   datetime.date(2017, 11, 6),
#   datetime.date(2011, 12, 15),
#   datetime.date(2016, 8, 23),
#   datetime.date(2008, 3, 23),
#   datetime.date(2015, 11, 8),
#   datetime.date(2015, 11, 7),
#   datetime.date(2007, 9, 2),
#   datetime.date(2011, 8, 6),
#   datetime.date(2017, 11, 12),
#   datetime.date(2008, 12, 29),
#   datetime.date(2013, 6, 12),
#   datetime.date(2009, 7, 15),
#   datetime.date(2018, 7, 8),
#   datetime.date(2008, 2, 12),
#   datetime.date(2020, 6, 24),
#   datetime.date(2012, 3, 18),
#   datetime.date(2018, 9, 6),
#   datetime.date(2014, 12, 6),
#   datetime.date(2010, 10, 24),
#   datetime.date(2015, 1, 1),
#   datetime.date(2014, 7, 24),
#   datetime.date(2008, 1, 25),
#   datetime.date(2016, 6, 22),
#   datetime.date(2019, 3, 1),
#   datetime.date(2010, 7, 19),
#   datetime.date(2008, 7, 20),
#   datetime.date(2007, 1, 6),
#   datetime.date(2008, 2, 19),
#   datetime.date(2018, 11, 28),
#   datetime.date(2009, 12, 28),
#   datetime.date(2008, 1, 21),
#   datetime.date(2012, 6, 22),
#   datetime.date(2016, 7, 5),
#   datetime.date(2012, 6, 17),
#   datetime.date(2010, 8, 3),
#   datetime.date(2007, 8, 20),
#   datetime.date(2007, 11, 25),
#   datetime.date(2008, 1, 19),
#   datetime.date(2011, 12, 23),
#   datetime.date(2010, 10, 15),
#   datetime.date(2010, 11, 20),
#   datetime.date(2012, 1, 31),
#   datetime.date(2012, 2, 12),
#   datetime.date(2005, 7, 12),
#   datetime.date(2007, 6, 15),
#   datetime.date(2005, 11, 5),
#   datetime.date(2007, 12, 27),
#   datetime.date(2009, 1, 24),
#   datetime.date(2016, 8, 6),
#   datetime.date(2011, 12, 12),
#   datetime.date(2016, 2, 5),
#   datetime.date(2012, 7, 29),
#   datetime.date(2016, 7, 6),
#   datetime.date(2014, 6, 14),
#   datetime.date(2009, 10, 12),
#   datetime.date(2019, 3, 25),
#   datetime.date(2014, 12, 28),
#   datetime.date(2011, 11, 27),
#   datetime.date(2020, 6, 20),
#   datetime.date(2007, 12, 9),
#   datetime.date(2018, 6, 9),
#   datetime.date(2005, 2, 2),
#   datetime.date(2009, 2, 21),
#   datetime.date(2019, 7, 13),
#   datetime.date(2010, 12, 18),
#   datetime.date(2013, 6, 22),
#   datetime.date(2008, 2, 5),
#   datetime.date(2010, 11, 30),
#   datetime.date(2008, 6, 6),
#   datetime.date(2007, 7, 29),
#   datetime.date(2014, 3, 28),
#   datetime.date(2011, 10, 27),
#   datetime.date(2006, 6, 10),
#   datetime.date(2011, 6, 23),
#   datetime.date(2016, 7, 15),
#   datetime.date(2007, 11, 17),
#   datetime.date(2009, 7, 8),
#   datetime.date(2005, 2, 9),
#   datetime.date(2005, 11, 14),
#   datetime.date(2007, 12, 12),
#   datetime.date(2010, 1, 4),
#   datetime.date(2020, 8, 22),
#   datetime.date(2008, 8, 5),
#   datetime.date(2017, 1, 22),
#   datetime.date(2012, 1, 13),
#   datetime.date(2008, 1, 18),
#   datetime.date(2010, 1, 14),
#   datetime.date(2007, 3, 2),
#   datetime.date(2006, 12, 14),
#   datetime.date(2008, 6, 13),
#   datetime.date(2005, 6, 11),
#   datetime.date(2007, 2, 25),
#   datetime.date(2008, 3, 24),
#   datetime.date(2014, 9, 25),
#   datetime.date(2007, 6, 24),
#   datetime.date(2007, 1, 25),
#   datetime.date(2008, 11, 11),
#   datetime.date(2017, 11, 29),
#   datetime.date(2008, 7, 27),
#   datetime.date(2012, 2, 3),
#   datetime.date(2010, 11, 9),
#   datetime.date(2010, 2, 14),
#   datetime.date(2016, 9, 1),
#   datetime.date(2012, 3, 2),
#   datetime.date(2010, 2, 24),
#   datetime.date(2008, 6, 20),
#   datetime.date(2010, 9, 8),
#   datetime.date(2009, 2, 23),
#   datetime.date(2010, 1, 3),
#   datetime.date(2009, 6, 4),
#   datetime.date(2015, 11, 22),
#   datetime.date(2013, 5, 13),
#   datetime.date(2015, 9, 6),
#   datetime.date(2015, 11, 21),
#   datetime.date(2010, 2, 15),
#   datetime.date(2011, 12, 3),
#   datetime.date(2007, 4, 28),
#   datetime.date(2017, 12, 31),
#   datetime.date(2015, 9, 3),
#   datetime.date(2016, 6, 20),
#   datetime.date(2009, 11, 13),
#   datetime.date(2010, 10, 26),
#   datetime.date(2010, 11, 28),
#   datetime.date(2018, 2, 1),
#   datetime.date(2005, 7, 4),
#   datetime.date(2008, 11, 8),
#   datetime.date(2011, 10, 1),
#   datetime.date(2020, 7, 27),
#   datetime.date(2007, 11, 6),
#   datetime.date(2012, 6, 18),
#   datetime.date(2015, 8, 27),
#   datetime.date(2011, 12, 18),
#   datetime.date(2007, 10, 31),
#   datetime.date(2005, 6, 13),
#   datetime.date(2009, 7, 26),
#   datetime.date(2011, 6, 26),
#   datetime.date(2016, 11, 8),
#   datetime.date(2009, 10, 31),
#   datetime.date(2007, 12, 23),
#   datetime.date(2012, 5, 26),
#   datetime.date(2012, 1, 27),
#   datetime.date(2016, 11, 10),
#   datetime.date(2019, 2, 9),
#   datetime.date(2020, 8, 17),
#   datetime.date(2005, 10, 20),
#   datetime.date(2006, 10, 20),
#   datetime.date(2007, 6, 23),
#   datetime.date(2005, 1, 3),
#   datetime.date(2014, 11, 30),
#   datetime.date(2009, 12, 2),
#   datetime.date(2007, 11, 28),
#   datetime.date(2016, 8, 31),
#   datetime.date(2008, 1, 3),
#   datetime.date(2011, 11, 18),
#   datetime.date(2011, 3, 11),
#   datetime.date(2010, 2, 28),
#   datetime.date(2009, 1, 26),
#   datetime.date(2006, 7, 16),
#   datetime.date(2008, 2, 11),
#   datetime.date(2010, 12, 27),
#   datetime.date(2017, 11, 13),
#   datetime.date(2015, 5, 30),
#   datetime.date(2008, 6, 10),
#   datetime.date(2010, 1, 2),
#   datetime.date(2017, 1, 15),
#   datetime.date(2005, 6, 27),
#   datetime.date(2011, 1, 15),
#   datetime.date(2009, 4, 15),
#   datetime.date(2008, 2, 15),
#   datetime.date(2008, 11, 19),
#   datetime.date(2008, 8, 6),
#   datetime.date(2013, 2, 25),
#   datetime.date(2009, 4, 3),
#   datetime.date(2012, 5, 13),
#   datetime.date(2013, 12, 14),
#   datetime.date(2012, 1, 8),
#   datetime.date(2008, 10, 4),
#   datetime.date(2006, 10, 15),
#   datetime.date(2010, 10, 31),
#   datetime.date(2008, 11, 2),
#   datetime.date(2007, 12, 7),
#   datetime.date(2015, 7, 2),
#   datetime.date(2005, 7, 3),
#   datetime.date(2014, 6, 18),
#   datetime.date(2020, 5, 23),
#   datetime.date(2011, 11, 25),
#   datetime.date(2013, 6, 14),
#   datetime.date(2009, 11, 8),
#   datetime.date(2014, 3, 5),
#   datetime.date(2010, 1, 31),
#   datetime.date(2015, 1, 2),
#   datetime.date(2011, 7, 18),
#   datetime.date(2017, 1, 4),
#   datetime.date(2009, 12, 29),
#   datetime.date(2009, 10, 28),
#   datetime.date(2013, 6, 2),
#   datetime.date(2010, 10, 3),
#   datetime.date(2009, 2, 22),
#   datetime.date(2009, 7, 16),
#   datetime.date(2011, 12, 16),
#   datetime.date(2011, 11, 6),
#   datetime.date(2008, 1, 17),
#   datetime.date(2007, 5, 31),
#   datetime.date(2007, 12, 15),
#   datetime.date(2009, 1, 23),
#   datetime.date(2018, 10, 10),
#   datetime.date(2007, 3, 7),
#   datetime.date(2008, 9, 23),
#   datetime.date(2014, 12, 7),
#   datetime.date(2019, 10, 5),
#   datetime.date(2014, 3, 15),
#   datetime.date(2015, 12, 23),
#   datetime.date(2014, 2, 5),
#   datetime.date(2009, 3, 15),
#   datetime.date(2013, 3, 3),
#   datetime.date(2009, 3, 2),
#   datetime.date(2007, 10, 12),
#   datetime.date(2011, 11, 9),
#   datetime.date(2010, 3, 8),
#   datetime.date(2006, 1, 27),
#   datetime.date(2008, 2, 10),
#   datetime.date(2012, 1, 14),
#   datetime.date(2016, 9, 15),
#   datetime.date(2006, 11, 6),
#   datetime.date(2016, 6, 8),
#   datetime.date(2010, 3, 6),
#   datetime.date(2020, 3, 14),
#   datetime.date(2015, 6, 22),
#   datetime.date(2007, 1, 8),
#   datetime.date(2012, 7, 20),
#   datetime.date(2005, 11, 24),
#   datetime.date(2015, 7, 15),
#   datetime.date(2011, 5, 23),
#   datetime.date(2013, 6, 15),
#   datetime.date(2010, 10, 2),
#   datetime.date(2008, 11, 23),
#   datetime.date(2008, 2, 13),
#   datetime.date(2009, 7, 12),
#   datetime.date(2008, 2, 6),
#   datetime.date(2007, 7, 3),
#   datetime.date(2016, 9, 24),
#   datetime.date(2011, 12, 10),
#   datetime.date(2010, 2, 18),
#   datetime.date(2008, 11, 12),
#   datetime.date(2020, 8, 19),
#   datetime.date(2012, 6, 27),
#   datetime.date(2005, 6, 29),
#   datetime.date(2015, 6, 24),
#   datetime.date(2014, 3, 23),
#   datetime.date(2015, 5, 19),
#   datetime.date(2015, 1, 23),
#   datetime.date(2009, 9, 21),
#   datetime.date(2017, 1, 2),
#   datetime.date(2010, 8, 23),
#   datetime.date(2020, 8, 21),
#   datetime.date(2007, 6, 14),
#   datetime.date(2015, 6, 23),
#   datetime.date(2016, 11, 9),
#   datetime.date(2011, 2, 15),
#   datetime.date(2015, 7, 23),
#   datetime.date(2007, 2, 27),
#   datetime.date(2012, 3, 5),
#   datetime.date(2020, 8, 15),
#   datetime.date(2008, 10, 13),
#   datetime.date(2005, 7, 20),
#   datetime.date(2011, 2, 6),
#   datetime.date(2011, 10, 26),
#   datetime.date(2005, 7, 15),
#   datetime.date(2018, 11, 27),
#   datetime.date(2015, 6, 16),
#   datetime.date(2005, 6, 30),
#   datetime.date(2020, 7, 11),
#   datetime.date(2020, 2, 25),
#   datetime.date(2012, 2, 21),
#   datetime.date(2014, 12, 27),
#   datetime.date(2010, 12, 24),
#   datetime.date(2010, 8, 7),
#   datetime.date(2006, 2, 20),
#   datetime.date(2015, 11, 6),
#   datetime.date(2009, 6, 27),
#   datetime.date(2010, 10, 21),
#   datetime.date(2020, 10, 29),
#   datetime.date(2016, 9, 17),
#   datetime.date(2007, 6, 22),
#   datetime.date(2007, 12, 21),
#   datetime.date(2012, 1, 1),
#   datetime.date(2006, 2, 4),
#   datetime.date(2016, 7, 23),
#   datetime.date(2013, 6, 28),
#   datetime.date(2020, 8, 24),
#   datetime.date(2009, 5, 25),
#   datetime.date(2010, 11, 1),
#   datetime.date(2013, 12, 26),
#   datetime.date(2017, 12, 30),
#   datetime.date(2010, 6, 18),
#   datetime.date(2015, 7, 4),
#   datetime.date(2018, 12, 22),
#   datetime.date(2008, 9, 1),
#   datetime.date(2016, 8, 26),
#   datetime.date(2016, 6, 23),
#   datetime.date(2016, 9, 10),
#   datetime.date(2014, 6, 4),
#   datetime.date(2010, 11, 18),
#   datetime.date(2014, 12, 5),
#   datetime.date(2005, 11, 8),
#   datetime.date(2007, 6, 27),
#   datetime.date(2007, 1, 3),
#   datetime.date(2016, 9, 18),
#   datetime.date(2013, 12, 9),
#   datetime.date(2011, 1, 5),
#   datetime.date(2013, 7, 1),
#   datetime.date(2011, 4, 11),
#   datetime.date(2016, 9, 13),
#   datetime.date(2010, 3, 1),
#   datetime.date(2010, 7, 14),
#   datetime.date(2015, 1, 24),
#   datetime.date(2006, 4, 30),
#   datetime.date(2017, 10, 11),
#   datetime.date(2015, 1, 11),
#   datetime.date(2020, 2, 9),
#   datetime.date(2012, 1, 28),
#   datetime.date(2009, 6, 8),
#   datetime.date(2008, 8, 10),
#   datetime.date(2016, 5, 26),
#   datetime.date(2019, 5, 2),
#   datetime.date(2006, 1, 18),
#   datetime.date(2014, 4, 6),
#   datetime.date(2015, 5, 31),
#   datetime.date(2008, 7, 6),
#   datetime.date(2010, 1, 28),
#   datetime.date(2011, 1, 9),
#   datetime.date(2010, 2, 2),
#   datetime.date(2015, 5, 24),
#   datetime.date(2007, 5, 18),
#   datetime.date(2016, 7, 21),
#   datetime.date(2018, 10, 4),
#   datetime.date(2008, 6, 23),
#   datetime.date(2020, 4, 9),
#   datetime.date(2008, 1, 22),
#   datetime.date(2020, 2, 23),
#   datetime.date(2008, 3, 8),
#   datetime.date(2008, 6, 14),
#   datetime.date(2017, 5, 19),
#   datetime.date(2007, 1, 24),
#   datetime.date(2020, 9, 13),
#   datetime.date(2010, 2, 9),
#   datetime.date(2010, 11, 26),
#   datetime.date(2012, 1, 2),
#   datetime.date(2015, 1, 29),
#   datetime.date(2011, 1, 11),
#   datetime.date(2010, 1, 30),
#   datetime.date(2016, 6, 27),
#   datetime.date(2010, 6, 25),
#   datetime.date(2005, 9, 11),
#   datetime.date(2005, 6, 22),
#   datetime.date(2015, 8, 24),
#   datetime.date(2008, 7, 7),
#   datetime.date(2008, 10, 14),
#   datetime.date(2009, 6, 10),
#   datetime.date(2016, 6, 26),
#   datetime.date(2016, 10, 22),
#   datetime.date(2005, 7, 14),
#   datetime.date(2011, 11, 21),
#   datetime.date(2016, 6, 19),
#   datetime.date(2011, 12, 6),
#   datetime.date(2008, 7, 11),
#   datetime.date(2011, 7, 16),
#   datetime.date(2006, 10, 24),
#   datetime.date(2008, 12, 20),
#   datetime.date(2006, 11, 5),
#   datetime.date(2010, 11, 10),
#   datetime.date(2013, 7, 19),
#   datetime.date(2018, 1, 1),
#   datetime.date(2007, 6, 26),
#   datetime.date(2012, 2, 26),
#   datetime.date(2010, 6, 2),
#   datetime.date(2009, 2, 16),
#   datetime.date(2018, 12, 13),
#   datetime.date(2014, 12, 23),
#   datetime.date(2014, 5, 3),
#   datetime.date(2008, 3, 22),
#   datetime.date(2013, 6, 13),
#   datetime.date(2010, 7, 27),
#   datetime.date(2012, 12, 8),
#   datetime.date(2011, 12, 25),
#   datetime.date(2007, 4, 27),
#   datetime.date(2015, 11, 15),
#   datetime.date(2010, 2, 5),
#   datetime.date(2014, 4, 4),
#   datetime.date(2010, 3, 7),
#   datetime.date(2017, 8, 5),
#   datetime.date(2016, 1, 4),
#   datetime.date(2016, 7, 13),
#   datetime.date(2009, 12, 30),
#   datetime.date(2011, 9, 28),
#   datetime.date(2013, 11, 22),
#   datetime.date(2005, 6, 23),
#   datetime.date(2007, 11, 23),
#   datetime.date(2015, 10, 27),
#   datetime.date(2017, 8, 4),
#   datetime.date(2011, 1, 6),
#   datetime.date(2015, 7, 8),
#   datetime.date(2012, 6, 3),
#   datetime.date(2010, 2, 7),
#   datetime.date(2005, 11, 13),
#   datetime.date(2007, 7, 21),
#   datetime.date(2009, 4, 10),
#   datetime.date(2005, 7, 8),
#   datetime.date(2015, 8, 29),
#   datetime.date(2009, 6, 22),
#   datetime.date(2019, 3, 30),
#   datetime.date(2016, 6, 17),
#   datetime.date(2017, 6, 17),
#   datetime.date(2010, 3, 30),
#   datetime.date(2017, 8, 12),
#   datetime.date(2005, 11, 7),
#   datetime.date(2017, 11, 20),
#   datetime.date(2007, 12, 28),
#   datetime.date(2020, 4, 30),
#   datetime.date(2009, 6, 9),
#   datetime.date(2012, 7, 1),
#   datetime.date(2011, 12, 8),
#   datetime.date(2010, 7, 29),
#   datetime.date(2008, 6, 4),
#   datetime.date(2012, 1, 30),
#   datetime.date(2013, 2, 24),
#   datetime.date(2006, 7, 25),
#   datetime.date(2012, 2, 1),
#   datetime.date(2009, 6, 20),
#   datetime.date(2007, 11, 1),
#   datetime.date(2016, 7, 26),
#   datetime.date(2014, 6, 23),
#   datetime.date(2008, 11, 24),
#   datetime.date(2007, 12, 26),
#   datetime.date(2020, 1, 20),
#   datetime.date(2016, 8, 21),
#   datetime.date(2020, 7, 6),
#   datetime.date(2017, 10, 6),
#   datetime.date(2018, 11, 20),
#   datetime.date(2007, 6, 19),
#   datetime.date(2006, 12, 27),
#   datetime.date(2010, 11, 27),
#   datetime.date(2016, 12, 7),
#   datetime.date(2010, 3, 9),
#   datetime.date(2008, 1, 26),
#   datetime.date(2010, 8, 12),
#   datetime.date(2014, 1, 10),
#   datetime.date(2010, 11, 8),
#   datetime.date(2006, 7, 27),
#   datetime.date(2007, 6, 30),
#   datetime.date(2015, 7, 11),
#   datetime.date(2010, 11, 7),
#   datetime.date(2006, 9, 3),
#   datetime.date(2010, 10, 30),
#   datetime.date(2006, 10, 17),
#   datetime.date(2006, 7, 2),
#   datetime.date(2010, 6, 3),
#   datetime.date(2015, 7, 24),
#   datetime.date(2016, 4, 30),
#   datetime.date(2006, 2, 25),
#   datetime.date(2007, 12, 13),
#   datetime.date(2016, 10, 31),
#   datetime.date(2007, 5, 20),
#   datetime.date(2005, 6, 10),
#   datetime.date(2020, 9, 30),
#   datetime.date(2013, 7, 14),
#   datetime.date(2010, 12, 12),
#   datetime.date(2016, 10, 30),
#   datetime.date(2020, 6, 23),
#   datetime.date(2020, 10, 16),
#   datetime.date(2010, 12, 25),
#   datetime.date(2012, 7, 14),
#   datetime.date(2015, 10, 29),
#   datetime.date(2010, 9, 10),
#   datetime.date(2006, 12, 26),
#   datetime.date(2006, 12, 20),
#   datetime.date(2014, 6, 19),
#   datetime.date(2007, 6, 20),
#   datetime.date(2010, 7, 3),
#   datetime.date(2010, 2, 13),
#   datetime.date(2015, 6, 17),
#   datetime.date(2016, 6, 11),
#   datetime.date(2008, 1, 8),
#   datetime.date(2010, 11, 14),
#   datetime.date(2010, 8, 14),
#   datetime.date(2009, 10, 23),
#   datetime.date(2006, 7, 28),
#   datetime.date(2016, 12, 6),
#   datetime.date(2015, 5, 21),
#   datetime.date(2010, 12, 17),
#   datetime.date(2008, 2, 2),
#   datetime.date(2011, 2, 19),
#   datetime.date(2006, 11, 3),
#   datetime.date(2010, 11, 16),
#   datetime.date(2008, 12, 14),
#   datetime.date(2008, 1, 20),
#   datetime.date(2010, 12, 3),
#   datetime.date(2010, 7, 11),
#   datetime.date(2020, 8, 12),
#   datetime.date(2009, 4, 5),
#   datetime.date(2013, 12, 4),
#   datetime.date(2017, 10, 28),
#   datetime.date(2009, 11, 9),
#   datetime.date(2015, 12, 26),
#   datetime.date(2020, 9, 24),
#   datetime.date(2007, 12, 5),
#   datetime.date(2007, 8, 17),
#   datetime.date(2010, 3, 5),
#   datetime.date(2007, 2, 17),
#   datetime.date(2009, 2, 9),
#   datetime.date(2010, 1, 1),
#   datetime.date(2005, 6, 19),
#   datetime.date(2016, 9, 25),
#   datetime.date(2008, 12, 27),
#   datetime.date(2016, 6, 9),
#   datetime.date(2020, 3, 5),
#   datetime.date(2020, 9, 4),
#   datetime.date(2020, 5, 24),
#   datetime.date(2007, 2, 24),
#   datetime.date(2005, 1, 24),
#   datetime.date(2008, 7, 12),
#   datetime.date(2012, 4, 25),
#   datetime.date(2010, 11, 29),
#   datetime.date(2009, 1, 10),
#   datetime.date(2010, 11, 24),
#   datetime.date(2010, 5, 31),
#   datetime.date(2007, 11, 22),
#   datetime.date(2020, 8, 7),
#   datetime.date(2010, 4, 7),
#   datetime.date(2010, 7, 31),
#   datetime.date(2016, 9, 16),
#   datetime.date(2005, 10, 16),
#   datetime.date(2014, 10, 24),
#   datetime.date(2018, 10, 7),
#   datetime.date(2005, 10, 19),
#   datetime.date(2016, 9, 14),
#   datetime.date(2005, 2, 27),
#   datetime.date(2015, 12, 27),
#   datetime.date(2009, 10, 5),
#   datetime.date(2007, 6, 10),
#   datetime.date(2008, 7, 26),
#   datetime.date(2011, 2, 13),
#   datetime.date(2006, 7, 21),
#   datetime.date(2010, 12, 19),
#   datetime.date(2015, 12, 21),
#   datetime.date(2011, 1, 21),
#   datetime.date(2010, 11, 13),
#   datetime.date(2014, 8, 18),
#   datetime.date(2007, 11, 3),
#   datetime.date(2010, 1, 8),
#   datetime.date(2008, 2, 25),
#   datetime.date(2020, 8, 28),
#   datetime.date(2008, 2, 20),
#   datetime.date(2018, 10, 13),
#   datetime.date(2010, 6, 26),
#   datetime.date(2014, 12, 31),
#   datetime.date(2015, 11, 16),
#   datetime.date(2015, 6, 20),
#   datetime.date(2009, 12, 31),
#   datetime.date(2007, 11, 4),
#   datetime.date(2016, 7, 1),
#   datetime.date(2006, 1, 29),
#   datetime.date(2014, 2, 14),
#   datetime.date(2010, 1, 29),
#   datetime.date(2010, 7, 15),
#   datetime.date(2019, 3, 8),
#   datetime.date(2013, 11, 18),
#   datetime.date(2014, 12, 30),
#   datetime.date(2008, 2, 7),
#   datetime.date(2011, 3, 22),
#   datetime.date(2014, 7, 15),
#   datetime.date(2012, 4, 14),
#   datetime.date(2014, 5, 4),
#   datetime.date(2019, 7, 8),
#   datetime.date(2008, 9, 5),
#   datetime.date(2020, 6, 9),
#   datetime.date(2020, 7, 5),
#   datetime.date(2020, 2, 14),
#   datetime.date(2011, 12, 20),
#   datetime.date(2015, 9, 2),
#   datetime.date(2015, 7, 16),
#   datetime.date(2012, 1, 18),
#   datetime.date(2010, 5, 30),
#   datetime.date(2010, 8, 1),
#   datetime.date(2010, 12, 28),
#   datetime.date(2007, 3, 9),
#   datetime.date(2009, 12, 27),
#   datetime.date(2008, 10, 10),
#   datetime.date(2013, 3, 1),
#   datetime.date(2009, 6, 5),
#   datetime.date(2018, 2, 24),
#   datetime.date(2009, 2, 10),
#   datetime.date(2009, 6, 28),
#   datetime.date(2012, 1, 20),
#   datetime.date(2007, 12, 25),
#   datetime.date(2005, 10, 21),
#   datetime.date(2010, 12, 26),
#   datetime.date(2009, 1, 12),
#   datetime.date(2017, 10, 8),
#   datetime.date(2020, 2, 24),
#   datetime.date(2014, 2, 28),
#   datetime.date(2008, 10, 12),
#   datetime.date(2016, 5, 9),
#   datetime.date(2007, 11, 2),
#   datetime.date(2009, 6, 13),
#   datetime.date(2020, 8, 10),
#   datetime.date(2017, 5, 21),
#   datetime.date(2008, 3, 21),
#   datetime.date(2016, 8, 12),
#   datetime.date(2012, 7, 12),
#   datetime.date(2005, 1, 23),
#   datetime.date(2007, 7, 14),
#   datetime.date(2010, 2, 6),
#   datetime.date(2009, 6, 1),
#   datetime.date(2012, 2, 27),
#   datetime.date(2009, 6, 2),
#   datetime.date(2012, 10, 21),
#   datetime.date(2020, 5, 2),
#   datetime.date(2011, 12, 30),
#   datetime.date(2008, 12, 4),
#   datetime.date(2006, 7, 24),
#   datetime.date(2005, 9, 16),
#   datetime.date(2010, 9, 19),
#   datetime.date(2014, 6, 20),
#   datetime.date(2008, 8, 31),
#   datetime.date(2012, 2, 5),
#   datetime.date(2020, 4, 3),
#   datetime.date(2016, 7, 3),
#   datetime.date(2012, 12, 7),
#   datetime.date(2008, 11, 21),
#   datetime.date(2010, 7, 28),
#   datetime.date(2007, 1, 2),
#   datetime.date(2006, 11, 4),
#   datetime.date(2010, 12, 8),
#   datetime.date(2005, 10, 14),
#   datetime.date(2006, 8, 29),
#   datetime.date(2008, 11, 16),
#   datetime.date(2020, 8, 9),
#   datetime.date(2008, 1, 1),
#   datetime.date(2020, 6, 21),
#   datetime.date(2014, 3, 1),
#   datetime.date(2006, 1, 11),
#   datetime.date(2011, 10, 6),
#   datetime.date(2011, 1, 30),
#   datetime.date(2012, 1, 5),
#   datetime.date(2011, 2, 7),
#   datetime.date(2014, 7, 14),
#   datetime.date(2008, 11, 15),
#   datetime.date(2009, 1, 2),
#   datetime.date(2008, 4, 28),
#   datetime.date(2006, 10, 22),
#   datetime.date(2015, 2, 21),
#   datetime.date(2015, 6, 21),
#   datetime.date(2009, 2, 18),
#   datetime.date(2007, 12, 24),
#   datetime.date(2020, 4, 7),
#   datetime.date(2020, 8, 31),
#   datetime.date(2013, 2, 3),
#   datetime.date(2017, 10, 23),
#   datetime.date(2007, 11, 9),
#   datetime.date(2016, 8, 30),
#   datetime.date(2018, 12, 11),
#   datetime.date(2008, 4, 5),
#   datetime.date(2009, 6, 26),
#   datetime.date(2010, 11, 21),
#   datetime.date(2005, 10, 23),
#   datetime.date(2009, 6, 24),
#   datetime.date(2007, 12, 31),
#   datetime.date(2015, 6, 27),
#   datetime.date(2007, 11, 11),
#   datetime.date(2015, 1, 28),
#   datetime.date(2008, 11, 17),
#   datetime.date(2010, 11, 15),
#   datetime.date(2011, 5, 13),
#   datetime.date(2013, 6, 27),
#   datetime.date(2020, 3, 6),
#   datetime.date(2008, 3, 1),
#   datetime.date(2005, 3, 27),
#   datetime.date(2014, 6, 15),
#   datetime.date(2013, 7, 15),
#   datetime.date(2015, 12, 16),
#   datetime.date(2020, 6, 14),
#   datetime.date(2009, 1, 9),
#   datetime.date(2016, 1, 6),
#   datetime.date(2014, 6, 13),
#   datetime.date(2015, 11, 3),
#   datetime.date(2006, 12, 24),
#   datetime.date(2020, 7, 14),
#   datetime.date(2010, 10, 16),
#   datetime.date(2016, 6, 24),
#   datetime.date(2005, 5, 1),
#   datetime.date(2007, 7, 8),
#   datetime.date(2012, 5, 4),
#   datetime.date(2017, 11, 15),
#   datetime.date(2009, 1, 18),
#   datetime.date(2010, 2, 20),
#   datetime.date(2015, 12, 28),
#   datetime.date(2008, 10, 6),
#   datetime.date(2014, 12, 19),
#   datetime.date(2012, 6, 28),
#   datetime.date(2012, 1, 26),
#   datetime.date(2017, 10, 22),
#   datetime.date(2011, 11, 28),
#   datetime.date(2011, 12, 27),
#   datetime.date(2009, 2, 15),
#   datetime.date(2016, 2, 23),
#   datetime.date(2015, 10, 30),
#   datetime.date(2005, 11, 20),
#   datetime.date(2006, 6, 23),
#   datetime.date(2014, 6, 2),
#   datetime.date(2020, 7, 12),
#   datetime.date(2013, 6, 24),
#   datetime.date(2005, 12, 28),
#   datetime.date(2008, 2, 3),
#   datetime.date(2007, 1, 1),
#   datetime.date(2010, 2, 21),
#   datetime.date(2016, 10, 17),
#   datetime.date(2010, 6, 23),
#   datetime.date(2011, 9, 9),
#   datetime.date(2009, 2, 13),
#   datetime.date(2006, 7, 20),
#   datetime.date(2017, 7, 1),
#   datetime.date(2007, 2, 18),
#   datetime.date(2015, 11, 19),
#   datetime.date(2020, 6, 27),
#   datetime.date(2016, 1, 22),
#   datetime.date(2008, 2, 8),
#   datetime.date(2020, 8, 14),
#   datetime.date(2009, 6, 15),
#   datetime.date(2012, 7, 23),
#   datetime.date(2009, 9, 22),
#   datetime.date(2010, 10, 13),
#   datetime.date(2006, 6, 24),
#   datetime.date(2013, 7, 24),
#   datetime.date(2011, 12, 26),
#   datetime.date(2006, 7, 17),
#   datetime.date(2010, 11, 17),
#   datetime.date(2020, 8, 13),
#   datetime.date(2010, 10, 23),
#   datetime.date(2012, 11, 11),
#   datetime.date(2009, 8, 2),
#   datetime.date(2011, 2, 17),
#   datetime.date(2019, 7, 12),
#   datetime.date(2007, 3, 1),
#   datetime.date(2006, 1, 12),
#   datetime.date(2015, 1, 13),
#   datetime.date(2017, 11, 22),
#   datetime.date(2010, 12, 7),
#   datetime.date(2017, 1, 6),
#   datetime.date(2008, 12, 7),
#   datetime.date(2006, 11, 7),
#   datetime.date(2010, 7, 8),
#   datetime.date(2014, 8, 16),
#   datetime.date(2009, 3, 14),
#   datetime.date(2012, 7, 2),
#   datetime.date(2009, 9, 3),
#   datetime.date(2005, 8, 7),
#   datetime.date(2011, 11, 17),
#   datetime.date(2007, 11, 26),
#   datetime.date(2008, 8, 22),
#   datetime.date(2015, 7, 9),
#   datetime.date(2011, 8, 19),
#   datetime.date(2006, 12, 28),
#   datetime.date(2011, 7, 17),
#   datetime.date(2005, 7, 1),
#   datetime.date(2010, 4, 27),
#   datetime.date(2009, 12, 18),
#   datetime.date(2010, 7, 7),
#   datetime.date(2014, 5, 10),
#   datetime.date(2008, 1, 13),
#   datetime.date(2005, 11, 26),
#   datetime.date(2005, 2, 20),
#   datetime.date(2010, 7, 24),
#   datetime.date(2020, 4, 10),
#   datetime.date(2010, 10, 25),
#   datetime.date(2007, 3, 5),
#   datetime.date(2020, 7, 26),
#   datetime.date(2016, 9, 22),
#   datetime.date(2008, 2, 1),
#   datetime.date(2014, 9, 1),
#   datetime.date(2009, 6, 6),
#   datetime.date(2008, 11, 18),
#   datetime.date(2015, 7, 18),
#   datetime.date(2011, 10, 29),
#   datetime.date(2013, 6, 5),
#   datetime.date(2007, 11, 7),
#   datetime.date(2009, 7, 1),
#   datetime.date(2014, 11, 11),
#   datetime.date(2013, 5, 22),
#   datetime.date(2016, 7, 12),
#   datetime.date(2017, 1, 20),
#   datetime.date(2008, 6, 26),
#   datetime.date(2016, 6, 6),
#   datetime.date(2007, 6, 17),
#   datetime.date(2010, 8, 5),
#   datetime.date(2010, 8, 10),
#   datetime.date(2011, 7, 7),
#   datetime.date(2014, 11, 25),
#   datetime.date(2013, 7, 20),
#   datetime.date(2015, 1, 12),
#   datetime.date(2015, 5, 20),
#   datetime.date(2010, 7, 30),
#   datetime.date(2020, 5, 20),
#   datetime.date(2015, 7, 25),
#   datetime.date(2009, 10, 4),
#   datetime.date(2008, 6, 28),
#   datetime.date(2018, 11, 21),
#   datetime.date(2018, 11, 18),
#   datetime.date(2017, 12, 21),
#   datetime.date(2020, 2, 22),
#   datetime.date(2008, 2, 14),
#   datetime.date(2005, 9, 5),
#   datetime.date(2010, 11, 6),
#   datetime.date(2006, 12, 25),
#   datetime.date(2018, 9, 2),
#   datetime.date(2017, 5, 20),
#   datetime.date(2010, 9, 13),
#   datetime.date(2016, 2, 7),
#   datetime.date(2013, 6, 29),
#   datetime.date(2016, 2, 27),
#   datetime.date(2005, 9, 26),
#   datetime.date(2010, 12, 1),
#   datetime.date(2012, 1, 25),
#   datetime.date(2009, 12, 25),
#   datetime.date(2010, 12, 10),
#   datetime.date(2013, 6, 3),
#   datetime.date(2020, 10, 17),
#   datetime.date(2011, 12, 24),
#   datetime.date(2011, 12, 22),
#   datetime.date(2015, 6, 28),
#   datetime.date(2009, 4, 12),
#   datetime.date(2005, 6, 20),
#   datetime.date(2020, 8, 11),
#   ...}}

# %%
find_missing_date(df2, region = ['NSW'])
# Out:
# {'NSW': set()}

# %%
df1['Date'] = pd.to_datetime(df1['Date'])
df1_temp = df1.copy()
df1_temp = df1[df1['Region'] == 'NSW']
df1_temp.reset_index(inplace = True)
df1_temp
# Out:
#       index Region       Date  Estimated_fire_area  \
# 0         0    NSW 2005-01-04              8.68000
# 1         1    NSW 2005-01-05             16.61125
# 2         2    NSW 2005-01-06              5.52000
# 3         3    NSW 2005-01-07              6.26400
# 4         4    NSW 2005-01-08              5.40000
# ...     ...    ...        ...                  ...
# 4618   4618    NSW 2020-10-25              3.00000
# 4619   4619    NSW 2020-10-27              1.21000
# 4620   4620    NSW 2020-10-28              3.00000
# 4621   4621    NSW 2020-10-30              1.32000
# 4622   4622    NSW 2020-10-31             20.27600
#
#       Mean_estimated_fire_brightness  Mean_estimated_fire_radiative_power  \
# 0                         312.266667                            42.400000
# 1                         322.475000                            62.362500
# 2                         325.266667                            38.400000
# 3                         313.870000                            33.800000
# 4                         337.383333                           122.533333
# ...                              ...                                  ...
# 4618                      324.233333                            27.966667
# 4619                      311.100000                            16.800000
# 4620                      323.166667                            20.566667
# 4621                      315.100000                            13.700000
# 4622                      315.040000                            88.460000
#
#       Mean_confidence  Std_confidence  Var_confidence  Count Replaced
# 0           78.666667        2.886751        8.333333      3        R
# 1           85.500000        8.088793       65.428571      8        R
# 2           78.333333        3.214550       10.333333      3        R
# 3           92.200000        7.529940       56.700000      5        R
# 4           91.000000        7.937254       63.000000      3        R
# ...               ...             ...             ...    ...      ...
# 4618        86.666667        3.511885       12.333333      3        N
# 4619        78.000000             NaN             NaN      1        N
# 4620        82.333333        4.509250       20.333333      3        N
# 4621        76.000000             NaN             NaN      1        N
# 4622        82.200000        6.418723       41.200000      5        N
#
# [4623 rows x 11 columns]

# %%
df2_temp = df2.copy()
df2_temp = df2[df2['Region'] == 'NSW']
df2_temp.reset_index(inplace = True)
df2_temp
# Out:
#       index       Date Region  Precipitation_Max  RelativeHumidity_Max  \
# 0         0 2005-01-01    NSW           1.836935             80.522964
# 1         7 2005-01-02    NSW           6.854537             86.243828
# 2        14 2005-01-03    NSW          14.969810             88.527359
# 3        21 2005-01-04    NSW          22.842566             90.332771
# 4        28 2005-01-05    NSW           7.657155             88.623436
# ...     ...        ...    ...                ...                   ...
# 5778  40446 2020-10-27    NSW          58.436600             97.393547
# 5779  40453 2020-10-28    NSW          30.506205             93.729408
# 5780  40460 2020-10-29    NSW          16.275040             91.932632
# 5781  40467 2020-10-30    NSW          46.937473             89.295311
# 5782  40474 2020-10-31    NSW          60.136063             97.623894
#
#       SoilWaterContent_Max  SolarRadiation_Max  Temperature_Max  \
# 0                 0.414305           32.169781        35.878704
# 1                 0.404071           34.308487        33.976604
# 2                 0.405569           32.525158        34.744976
# 3                 0.444927           33.214062        28.945488
# 4                 0.442955           33.554867        29.510120
# ...                    ...                 ...              ...
# 5778              0.468511           29.975296        22.218430
# 5779              0.494503           29.948700        22.422768
# 5780              0.480009           29.375010        24.129215
# 5781              0.484731           29.318480        24.310499
# 5782              0.475204           29.834957        22.036409
#
#       WindSpeed_Max  Precipitation_Mean  ...  SoilWaterContent_Min  \
# 0          7.670482            0.044274  ...              0.002245
# 1          7.448905            0.173879  ...              0.001210
# 2          8.515941            3.011912  ...              0.010889
# 3          7.364222            2.808620  ...              0.022578
# 4          7.091141            0.157935  ...              0.019950
# ...             ...                 ...  ...                   ...
# 5778       5.497386            2.124025  ...              0.007598
# 5779       4.353423            4.350241  ...              0.000000
# 5780       7.925164            2.342508  ...              0.004790
# 5781       8.527669            6.023114  ...              0.008776
# 5782       7.461010            2.569159  ...              0.012940
#
#       SolarRadiation_Min  Temperature_Min  WindSpeed_Min  \
# 0              14.515009        14.485785       1.354448
# 1              15.775055        12.067627       0.864556
# 2              15.362626        16.858456       1.435490
# 3               7.576938        12.495799       1.401951
# 4              14.087289         9.611800       1.011328
# ...                  ...              ...            ...
# 5778            8.514027         7.288919       1.036175
# 5779            9.952868         8.654533       0.790777
# 5780           15.170402         9.860389       0.663298
# 5781            8.277431        10.133630       1.465277
# 5782            5.178627         8.298871       1.327121
#
#       Precipitation_Variance  RelativeHumidity_Variance  \
# 0                   0.028362                 253.559937
# 1                   0.271386                 224.769253
# 2                  10.308246                 167.044018
# 3                  17.383363                 267.158378
# 4                   0.273471                 195.639724
# ...                      ...                        ...
# 5778               19.255058                 305.295409
# 5779               33.377184                 363.242021
# 5780               12.204651                 326.339825
# 5781               48.708134                 272.160953
# 5782               38.524171                 160.672680
#
#       SoilWaterContent_Variance  SolarRadiation_Variance  \
# 0                      0.007758                 6.078587
# 1                      0.007293                11.737577
# 2                      0.006598                 6.106235
# 3                      0.009965                40.255460
# 4                      0.009483                29.763055
# ...                         ...                      ...
# 5778                   0.013978                23.311615
# 5779                   0.016336                12.846223
# 5780                   0.015407                 9.261971
# 5781                   0.014347                17.436028
# 5782                   0.013632                16.523703
#
#       Temperature_Variance  WindSpeed_Variance
# 0                18.562212            0.850048
# 1                22.320857            0.470928
# 2                16.619341            2.002952
# 3                 9.455474            1.494301
# 4                13.352380            1.043316
# ...                    ...                 ...
# 5778              8.529138            0.613602
# 5779              7.148141            0.562205
# 5780             11.601502            2.072462
# 5781              6.171237            2.912816
# 5782              7.320792            0.745520
#
# [5783 rows x 27 columns]

# %%
df = pd.merge(df1_temp, df2_temp, how='inner', on=['Date','Region']).drop('index_x', axis = 1)

## Note that there were lot of missing targets (5783 - 4623 = 1160 days)
df
# Out:
#      Region       Date  Estimated_fire_area  Mean_estimated_fire_brightness  \
# 0       NSW 2005-01-04              8.68000                      312.266667
# 4                12.063971            0.774612
# ...                    ...                 ...
# 4618              6.921498            1.977909
# 4619              8.529138            0.613602
# 4620              7.148141            0.562205
# 4621              6.171237            2.912816
# 4622              7.320792            0.745520
#
# [4623 rows x 35 columns]

# %%
df[['Date','Region']].values
# Out:
# array([[Timestamp('2005-01-04 00:00:00'), 'NSW'],
#        [Timestamp('2005-01-05 00:00:00'), 'NSW'],
#        [Timestamp('2005-01-06 00:00:00'), 'NSW'],
#        ...,
#        [Timestamp('2020-10-28 00:00:00'), 'NSW'],
#        [Timestamp('2020-10-30 00:00:00'), 'NSW'],
#        [Timestamp('2020-10-31 00:00:00'), 'NSW']], dtype=object)

# %%
plt.figure(figsize=(16, 6))
sns.set(style="whitegrid")
g = sns.lineplot(x="Date", y="Estimated_fire_area",hue='Region',
                 data=df)
g.set_yscale("log")

# %%
df['Date'][0].date().year
df['Year'] = pd.DatetimeIndex(df['Date']).year

# %%
df.columns.values
# Out:
# array(['Region', 'Date', 'Estimated_fire_area',
#        'Mean_estimated_fire_brightness',
#        'Mean_estimated_fire_radiative_power', 'Mean_confidence',
#        'Std_confidence', 'Var_confidence', 'Count', 'Replaced', 'index_y',
#        'Precipitation_Max', 'RelativeHumidity_Max',
#        'SoilWaterContent_Max', 'SolarRadiation_Max', 'Temperature_Max',
#        'WindSpeed_Max', 'Precipitation_Mean', 'RelativeHumidity_Mean',
#        'SoilWaterContent_Mean', 'SolarRadiation_Mean', 'Temperature_Mean',
#        'WindSpeed_Mean', 'Precipitation_Min', 'RelativeHumidity_Min',
#        'SoilWaterContent_Min', 'SolarRadiation_Min', 'Temperature_Min',
#        'WindSpeed_Min', 'Precipitation_Variance',
#        'RelativeHumidity_Variance', 'SoilWaterContent_Variance',
#        'SolarRadiation_Variance', 'Temperature_Variance',
#        'WindSpeed_Variance', 'Year'], dtype=object)

# %%
annually = df[['Year', 'Estimated_fire_area']].groupby('Year').mean().copy()
plt.figure(figsize = (16,6))
sns.set(style = "whitegrid")
sns.lineplot(x = "Year", y = "Estimated_fire_area", data=annually)

#quite stationary except 2019-2020 (especailly  2019)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Estimated_fire_area'>

# %%
def gen_supervise(df, ft_cols = None, tgt_col = 'Estimated_fire_area', lag = 7, forecast = 30) :

    ft = list(df.values)
    tgt = list(df[tgt_col].values)
    
    ft = [ft[i:i+lag] for i in range(len(tgt)-forecast-lag+1)]
    ft = np.array([list(itertools.chain(*temp)) for temp in ft])
    target = np.array([tgt[i : i + forecast] for i in range(lag,len(tgt)-forecast+1)])
    
    return ft, target

    
def prepared_data(df, split = 0.8, lag = 30, forecast = 30, ft_cols = None) :

    if ft_cols == None :
        ft_cols = [ft for ft in df.columns.values if ft not in ['Date', 'Region','Replaced']]
    ttl_rows =  len(df.index.values)
    temp_df = df[ft_cols]
    
    split_idx = round(split*ttl_rows)
    scaler = MinMaxScaler(feature_range=(0,1))
    train, test = temp_df.iloc[:split_idx, :], temp_df.iloc[split_idx:, :]
    
    scaled_train = scaler.fit_transform(train)
    scaled_train_df = pd.DataFrame(scaled_train, columns=ft_cols)
    scaled_test = scaler.transform(test)
    scaled_test_df = pd.DataFrame(scaled_test, columns=ft_cols)
    
    scaled_data = dict()
    scaled_data['X_train'], scaled_data['y_train'] = gen_supervise(scaled_train_df, lag = lag, forecast = forecast, ft_cols = ft_cols)
    scaled_data['X_test'], scaled_data['y_test'] = gen_supervise(scaled_test_df, lag = lag, forecast = forecast)
    
    data = dict()
    data['X_train'], data['y_train'] = gen_supervise(train, lag = lag, forecast = forecast, ft_cols = ft_cols)
    data['X_test'], data['y_test'] = gen_supervise(test, lag = lag, forecast = forecast, ft_cols = ft_cols)
    
    return scaler, data, scaled_data, train, test

# %%
scaler, data, scaled_data, _, _ = prepared_data(df, forecast=7, lag=15,ft_cols = ['Estimated_fire_area','Mean_estimated_fire_brightness','Mean_estimated_fire_radiative_power'])

# %%
print(data['X_train'].shape)
print(data['y_train'].shape)
print(data['X_test'].shape)
print(data['y_test'].shape)
# Out:
# (3677, 45)
# (3677, 7)
# (904, 45)
# (904, 7)

# %%
def LSTM_model(data, opt_params, n_batch=1, nb_epoch=500, n_neurons=32):
    # reshape training into [samples, timesteps, features]
    X, y = data['X_train'], data['y_train']
    X = X.reshape(X.shape[0], 1, X.shape[1])
    log = []
    
    # design network
    model = Sequential()
    model.add(LSTM(n_neurons, batch_input_shape=(n_batch, X.shape[1], X.shape[2]), stateful=True))
    model.add(Dense(y.shape[1]))
    opt = Adam(**opt_params)
    model.compile(loss='mean_squared_error', optimizer=opt)
    
    # fit network
    for i in range(nb_epoch):
        history = model.fit(X, y, epochs=1, batch_size=n_batch, verbose=0, shuffle=False)
        print(f'''training at iteration : {i+1}/{nb_epoch} --- train_loss : {history.history['loss']}''')
        log.append(history.history['loss'][0])
        model.reset_states()
    return model, log

# %%
def LSTM_forecast(df, model, scaler, n_batch = 1, lag = 30, forecast = 30, ft_cols = None) :
    if ft_cols == None :
        ft_cols = [ft for ft in df.columns.values if ft not in ['Date', 'Region','Replaced']]
    scaled_test = scaler.transform(df)
    scaled_test_df = pd.DataFrame(scaled_test, columns = ft_cols)
    X_test, y_test = gen_supervise(scaled_test_df,lag = lag, forecast = forecast, ft_cols = ft_cols)
    test_size = X_test.shape[0]
    pred = []
    for i in range(test_size) :
        X = X_test[i]
        X = X.reshape(1,1,X.shape[0])
        res = model.predict(X, batch_size = n_batch)
        pred.append(res[0])
    return pred

def inverse_pred(scaler, pred) :
    y_hat = []
    
    #the prediction is scaled -> inverse scale back
    tgt_scaler = MinMaxScaler()
    tgt_scaler.min_, tgt_scaler.scale_ = scaler.min_[0], scaler.scale_[0] #index of the target feature b4 transform
    for p in pred :
        inverted = tgt_scaler.inverse_transform(p.reshape(p.shape[0],1)).reshape(p.shape[0])
        y_hat.append(inverted)       
    return np.array(y_hat)

# %%
opt_params = {
    'lr' : 0.05,
    'beta_1' : 0.9,
    'beta_2' : 0.999,
    'decay' : 0.01
}

model = LSTM_model(scaled_data,opt_params, nb_epoch=1000)
# Out:
# training at iteration : 1/1000 --- train_loss : [0.0008967596587462557]
# training at iteration : 2/1000 --- train_loss : [0.0008188609905813952]
# training at iteration : 3/1000 --- train_loss : [0.0008313001685574244]
# training at iteration : 4/1000 --- train_loss : [0.0008297578668132263]
# training at iteration : 5/1000 --- train_loss : [0.0008149479687485112]
# training at iteration : 6/1000 --- train_loss : [0.0007975675824733146]
# training at iteration : 7/1000 --- train_loss : [0.0007847196972522225]
# training at iteration : 8/1000 --- train_loss : [0.0007754757010734649]
# training at iteration : 9/1000 --- train_loss : [0.0007686743118572114]
# training at iteration : 10/1000 --- train_loss : [0.0007635377783749418]
# training at iteration : 11/1000 --- train_loss : [0.0007595375932104231]
# training at iteration : 12/1000 --- train_loss : [0.0007563304553528827]
# training at iteration : 13/1000 --- train_loss : [0.0007536930207153326]
# training at iteration : 14/1000 --- train_loss : [0.0007514771263490882]
# training at iteration : 15/1000 --- train_loss : [0.0007495815129416863]
# training at iteration : 16/1000 --- train_loss : [0.0007479349265362882]
# training at iteration : 17/1000 --- train_loss : [0.0007464858112815975]
# training at iteration : 18/1000 --- train_loss : [0.0007451957864484912]
# training at iteration : 19/1000 --- train_loss : [0.0007440359342419208]
# training at iteration : 20/1000 --- train_loss : [0.0007429839055094858]
# training at iteration : 21/1000 --- train_loss : [0.0007420223333481651]
# training at iteration : 22/1000 --- train_loss : [0.0007411374235249312]
# training at iteration : 23/1000 --- train_loss : [0.0007403183388603285]
# training at iteration : 24/1000 --- train_loss : [0.0007395561748154625]
# training at iteration : 25/1000 --- train_loss : [0.0007388437738389674]
# training at iteration : 26/1000 --- train_loss : [0.0007381752752982375]
# training at iteration : 27/1000 --- train_loss : [0.0007375457127745226]
# training at iteration : 28/1000 --- train_loss : [0.0007369510020640034]
# training at iteration : 29/1000 --- train_loss : [0.0007363876926987132]
# training at iteration : 30/1000 --- train_loss : [0.0007358527859476387]
# training at iteration : 31/1000 --- train_loss : [0.0007353437372999591]
# training at iteration : 32/1000 --- train_loss : [0.0007348583939565787]
# training at iteration : 33/1000 --- train_loss : [0.0007343947773276349]
# training at iteration : 34/1000 --- train_loss : [0.000733951244462026]
# training at iteration : 35/1000 --- train_loss : [0.0007335263118566509]
# training at iteration : 36/1000 --- train_loss : [0.0007331186157412715]
# training at iteration : 37/1000 --- train_loss : [0.0007327270501393191]
# training at iteration : 38/1000 --- train_loss : [0.0007323505363211605]
# training at iteration : 39/1000 --- train_loss : [0.000731988141134472]
# training at iteration : 40/1000 --- train_loss : [0.000731639006749948]
# training at iteration : 41/1000 --- train_loss : [0.0007313023444252516]
# training at iteration : 42/1000 --- train_loss : [0.0007309774744897609]
# training at iteration : 43/1000 --- train_loss : [0.0007306637047795144]
# training at iteration : 44/1000 --- train_loss : [0.0007303604747509691]
# training at iteration : 45/1000 --- train_loss : [0.0007300672026901577]
# training at iteration : 46/1000 --- train_loss : [0.0007297833988662143]
# training at iteration : 47/1000 --- train_loss : [0.0007295086030489723]
# training at iteration : 48/1000 --- train_loss : [0.0007292423555291467]
# training at iteration : 49/1000 --- train_loss : [0.0007289842491778155]
# training at iteration : 383/1000 --- train_loss : [0.0007102707172222386]
# training at iteration : 384/1000 --- train_loss : [0.0007102499378558922]
# training at iteration : 385/1000 --- train_loss : [0.0007102292506807285]
# training at iteration : 386/1000 --- train_loss : [0.0007102085885243059]
# training at iteration : 387/1000 --- train_loss : [0.0007101879988385892]
# training at iteration : 388/1000 --- train_loss : [0.0007101674488028964]
# training at iteration : 389/1000 --- train_loss : [0.0007101469970170877]
# training at iteration : 390/1000 --- train_loss : [0.0007101265993164085]
# training at iteration : 391/1000 --- train_loss : [0.0007101062464215765]
# training at iteration : 392/1000 --- train_loss : [0.000710085993478932]
# training at iteration : 393/1000 --- train_loss : [0.0007100657622230182]
# training at iteration : 394/1000 --- train_loss : [0.0007100456268254527]
# training at iteration : 395/1000 --- train_loss : [0.000710025528397165]
# training at iteration : 396/1000 --- train_loss : [0.0007100055078446084]
# training at iteration : 397/1000 --- train_loss : [0.0007099855646710485]
# training at iteration : 398/1000 --- train_loss : [0.0007099656338883647]
# training at iteration : 399/1000 --- train_loss : [0.0007099458083689019]
# training at iteration : 400/1000 --- train_loss : [0.0007099260030604979]
# training at iteration : 401/1000 --- train_loss : [0.0007099062765565508]
# training at iteration : 402/1000 --- train_loss : [0.0007098866144150915]
# training at iteration : 403/1000 --- train_loss : [0.0007098670077650217]
# training at iteration : 404/1000 --- train_loss : [0.000709847477386329]
# training at iteration : 405/1000 --- train_loss : [0.0007098279887329319]
# training at iteration : 406/1000 --- train_loss : [0.0007098085466166249]
# training at iteration : 407/1000 --- train_loss : [0.0007097891645860533]
# training at iteration : 408/1000 --- train_loss : [0.0007097698772748903]
# training at iteration : 409/1000 --- train_loss : [0.0007097506144037074]
# training at iteration : 410/1000 --- train_loss : [0.0007097313940364065]
# training at iteration : 411/1000 --- train_loss : [0.0007097122482167218]
# training at iteration : 412/1000 --- train_loss : [0.0007096931431712219]
# training at iteration : 413/1000 --- train_loss : [0.0007096741050482504]
# training at iteration : 414/1000 --- train_loss : [0.0007096551173497973]
# training at iteration : 415/1000 --- train_loss : [0.0007096361720995421]
# training at iteration : 416/1000 --- train_loss : [0.0007096173276547906]
# training at iteration : 417/1000 --- train_loss : [0.0007095985114526695]
# training at iteration : 418/1000 --- train_loss : [0.0007095797550247501]
# training at iteration : 419/1000 --- train_loss : [0.0007095610285474844]
# training at iteration : 420/1000 --- train_loss : [0.0007095423637439213]
# training at iteration : 421/1000 --- train_loss : [0.0007095237705700845]
# training at iteration : 422/1000 --- train_loss : [0.0007095052413898482]
# training at iteration : 423/1000 --- train_loss : [0.000709486745837387]
# training at iteration : 424/1000 --- train_loss : [0.0007094683027988767]
# training at iteration : 425/1000 --- train_loss : [0.0007094498982041409]
# training at iteration : 426/1000 --- train_loss : [0.0007094315582727903]
# training at iteration : 427/1000 --- train_loss : [0.0007094132561441219]
# training at iteration : 428/1000 --- train_loss : [0.0007093950081159185]
# training at iteration : 429/1000 --- train_loss : [0.000709376825811693]
# training at iteration : 430/1000 --- train_loss : [0.0007093586724168523]
# training at iteration : 479/1000 --- train_loss : [0.0007085273761653538]
# training at iteration : 480/1000 --- train_loss : [0.0007085114932458745]
# training at iteration : 481/1000 --- train_loss : [0.0007084956787970372]
# training at iteration : 482/1000 --- train_loss : [0.0007084798592848226]
# training at iteration : 483/1000 --- train_loss : [0.0007084640791047291]
# training at iteration : 484/1000 --- train_loss : [0.0007084483654817398]
# training at iteration : 485/1000 --- train_loss : [0.000708432654785205]
# training at iteration : 486/1000 --- train_loss : [0.0007084170104653347]
# training at iteration : 487/1000 --- train_loss : [0.0007084013939237317]
# training at iteration : 488/1000 --- train_loss : [0.0007083858026164638]
# training at iteration : 489/1000 --- train_loss : [0.0007083702742137896]
# training at iteration : 490/1000 --- train_loss : [0.0007083547573094399]
# training at iteration : 491/1000 --- train_loss : [0.0007083393482367002]
# training at iteration : 492/1000 --- train_loss : [0.0007083239039310274]
# training at iteration : 493/1000 --- train_loss : [0.0007083085127668865]
# training at iteration : 494/1000 --- train_loss : [0.0007082931446925207]
# training at iteration : 495/1000 --- train_loss : [0.0007082778672115381]
# training at iteration : 496/1000 --- train_loss : [0.0007082625977111428]
# training at iteration : 497/1000 --- train_loss : [0.0007082473608153101]
# training at iteration : 498/1000 --- train_loss : [0.0007082321613974859]
# training at iteration : 499/1000 --- train_loss : [0.0007082170076307243]
# training at iteration : 500/1000 --- train_loss : [0.0007082019031840769]
# training at iteration : 501/1000 --- train_loss : [0.0007081868045108163]
# training at iteration : 502/1000 --- train_loss : [0.0007081717681674699]
# training at iteration : 503/1000 --- train_loss : [0.0007081567372906764]
# training at iteration : 504/1000 --- train_loss : [0.0007081418046412585]
# training at iteration : 505/1000 --- train_loss : [0.000708126870281653]
# training at iteration : 506/1000 --- train_loss : [0.0007081119985210131]
# training at iteration : 507/1000 --- train_loss : [0.0007080971219145685]
# training at iteration : 508/1000 --- train_loss : [0.0007080823184160572]
# training at iteration : 509/1000 --- train_loss : [0.0007080675174448442]
# training at iteration : 510/1000 --- train_loss : [0.0007080527406293325]
# training at iteration : 511/1000 --- train_loss : [0.0007080380572004004]
# training at iteration : 512/1000 --- train_loss : [0.0007080233599336283]
# training at iteration : 513/1000 --- train_loss : [0.000708008701635269]
# training at iteration : 514/1000 --- train_loss : [0.0007079940577255759]
# training at iteration : 515/1000 --- train_loss : [0.0007079794638472126]
# training at iteration : 516/1000 --- train_loss : [0.0007079649115391818]
# training at iteration : 517/1000 --- train_loss : [0.0007079503774120632]
# training at iteration : 518/1000 --- train_loss : [0.0007079358893173389]
# training at iteration : 519/1000 --- train_loss : [0.0007079214750657096]
# training at iteration : 520/1000 --- train_loss : [0.0007079070436012219]
# training at iteration : 521/1000 --- train_loss : [0.0007078926621460036]
# training at iteration : 522/1000 --- train_loss : [0.0007078782992126962]
# training at iteration : 523/1000 --- train_loss : [0.0007078639861851898]
# training at iteration : 524/1000 --- train_loss : [0.0007078496936034278]
# training at iteration : 525/1000 --- train_loss : [0.0007078354503864882]
# training at iteration : 574/1000 --- train_loss : [0.0007071747027490746]
# training at iteration : 575/1000 --- train_loss : [0.000707161960421438]
# training at iteration : 576/1000 --- train_loss : [0.0007071492135328166]
# training at iteration : 577/1000 --- train_loss : [0.00070713649905963]
# training at iteration : 578/1000 --- train_loss : [0.0007071238198208607]
# training at iteration : 579/1000 --- train_loss : [0.0007071111446988874]
# training at iteration : 580/1000 --- train_loss : [0.0007070985024926084]
# training at iteration : 581/1000 --- train_loss : [0.0007070859133758564]
# training at iteration : 582/1000 --- train_loss : [0.0007070733395323451]
# training at iteration : 583/1000 --- train_loss : [0.000707060773159268]
# training at iteration : 584/1000 --- train_loss : [0.0007070482293119377]
# training at iteration : 585/1000 --- train_loss : [0.0007070357327726471]
# training at iteration : 586/1000 --- train_loss : [0.0007070232590994371]
# training at iteration : 587/1000 --- train_loss : [0.0007070108376452323]
# training at iteration : 588/1000 --- train_loss : [0.0007069983746083581]
# training at iteration : 589/1000 --- train_loss : [0.0007069859833940327]
# training at iteration : 590/1000 --- train_loss : [0.0007069736323056111]
# training at iteration : 591/1000 --- train_loss : [0.0007069612827277993]
# training at iteration : 592/1000 --- train_loss : [0.0007069489486042705]
# training at iteration : 593/1000 --- train_loss : [0.0007069366369150011]
# training at iteration : 594/1000 --- train_loss : [0.0007069243580956668]
# training at iteration : 595/1000 --- train_loss : [0.0007069121019766287]
# training at iteration : 596/1000 --- train_loss : [0.000706899868458732]
# training at iteration : 597/1000 --- train_loss : [0.0007068876505528486]
# training at iteration : 598/1000 --- train_loss : [0.000706875480626799]
# training at iteration : 599/1000 --- train_loss : [0.0007068633252840624]
# training at iteration : 600/1000 --- train_loss : [0.0007068511960599106]
# training at iteration : 601/1000 --- train_loss : [0.000706839082237558]
# training at iteration : 602/1000 --- train_loss : [0.0007068270187324371]
# training at iteration : 603/1000 --- train_loss : [0.0007068149728921854]
# training at iteration : 604/1000 --- train_loss : [0.0007068029343474937]
# training at iteration : 605/1000 --- train_loss : [0.0007067909297747756]
# training at iteration : 606/1000 --- train_loss : [0.0007067789223104019]
# training at iteration : 607/1000 --- train_loss : [0.0007067669733877001]
# training at iteration : 608/1000 --- train_loss : [0.0007067550375545521]
# training at iteration : 609/1000 --- train_loss : [0.0007067431235503127]
# training at iteration : 610/1000 --- train_loss : [0.0007067312516778062]
# training at iteration : 611/1000 --- train_loss : [0.0007067193835987981]
# training at iteration : 612/1000 --- train_loss : [0.0007067075611709915]
# training at iteration : 613/1000 --- train_loss : [0.0007066957430187623]
# training at iteration : 614/1000 --- train_loss : [0.0007066839585847599]
# training at iteration : 615/1000 --- train_loss : [0.0007066722088851009]
# training at iteration : 616/1000 --- train_loss : [0.000706660452534994]
# training at iteration : 617/1000 --- train_loss : [0.0007066487406444792]
# training at iteration : 618/1000 --- train_loss : [0.0007066370389380419]
# training at iteration : 619/1000 --- train_loss : [0.000706625385411635]
# training at iteration : 620/1000 --- train_loss : [0.0007066137100897269]
# training at iteration : 621/1000 --- train_loss : [0.0007066020822381798]
# training at iteration : 622/1000 --- train_loss : [0.0007065904694537252]
# training at iteration : 623/1000 --- train_loss : [0.0007065788742589619]
# training at iteration : 624/1000 --- train_loss : [0.0007065673112173531]
# training at iteration : 625/1000 --- train_loss : [0.0007065557529668853]
# training at iteration : 626/1000 --- train_loss : [0.000706544231521457]
# training at iteration : 627/1000 --- train_loss : [0.000706532712904178]
# training at iteration : 628/1000 --- train_loss : [0.0007065212173903402]
# training at iteration : 629/1000 --- train_loss : [0.0007065097744670996]
# training at iteration : 630/1000 --- train_loss : [0.0007064983184750362]
# training at iteration : 631/1000 --- train_loss : [0.0007064868729059718]
# training at iteration : 632/1000 --- train_loss : [0.000706475465930868]
# training at iteration : 633/1000 --- train_loss : [0.0007064641036624562]
# training at iteration : 634/1000 --- train_loss : [0.0007064527177184435]
# training at iteration : 635/1000 --- train_loss : [0.000706441401060251]
# training at iteration : 636/1000 --- train_loss : [0.0007064301358918229]
# training at iteration : 637/1000 --- train_loss : [0.0007064188467459379]
# training at iteration : 638/1000 --- train_loss : [0.0007064075821291863]
# training at iteration : 639/1000 --- train_loss : [0.0007063963558702871]
# training at iteration : 640/1000 --- train_loss : [0.0007063851362622689]
# training at iteration : 641/1000 --- train_loss : [0.0007063739212344822]
# training at iteration : 642/1000 --- train_loss : [0.0007063627479628785]
# training at iteration : 643/1000 --- train_loss : [0.0007063515724846618]
# training at iteration : 644/1000 --- train_loss : [0.0007063404458201785]
# training at iteration : 645/1000 --- train_loss : [0.0007063293075872941]
# training at iteration : 646/1000 --- train_loss : [0.0007063182008139261]
# training at iteration : 647/1000 --- train_loss : [0.0007063071271145697]
# training at iteration : 648/1000 --- train_loss : [0.0007062960525341173]
# training at iteration : 649/1000 --- train_loss : [0.0007062850130372775]
# training at iteration : 650/1000 --- train_loss : [0.0007062739881178452]
# training at iteration : 651/1000 --- train_loss : [0.0007062629987862734]
# ...
# training at iteration : 785/1000 --- train_loss : [0.0007049492816321939]
# training at iteration : 786/1000 --- train_loss : [0.0007049405273321253]
# training at iteration : 787/1000 --- train_loss : [0.0007049317681652659]
# training at iteration : 788/1000 --- train_loss : [0.0007049230259571467]
# training at iteration : 789/1000 --- train_loss : [0.0007049142734750703]
# training at iteration : 790/1000 --- train_loss : [0.0007049055724818539]
# training at iteration : 791/1000 --- train_loss : [0.0007048968337390576]
# training at iteration : 792/1000 --- train_loss : [0.0007048881360856202]
# training at iteration : 793/1000 --- train_loss : [0.0007048794076885193]
# training at iteration : 794/1000 --- train_loss : [0.0007048707554488228]
# training at iteration : 795/1000 --- train_loss : [0.0007048621003840763]
# training at iteration : 796/1000 --- train_loss : [0.0007048534435915804]
# training at iteration : 797/1000 --- train_loss : [0.0007048448303780601]
# training at iteration : 798/1000 --- train_loss : [0.0007048361914678437]
# training at iteration : 799/1000 --- train_loss : [0.000704827591831622]
# training at iteration : 800/1000 --- train_loss : [0.0007048189743867298]
# training at iteration : 801/1000 --- train_loss : [0.0007048104122859474]
# training at iteration : 802/1000 --- train_loss : [0.0007048018069319301]
# training at iteration : 803/1000 --- train_loss : [0.0007047932458154109]
# training at iteration : 804/1000 --- train_loss : [0.000704784708530352]
# training at iteration : 805/1000 --- train_loss : [0.0007047761665105392]
# training at iteration : 806/1000 --- train_loss : [0.0007047676641695431]
# training at iteration : 807/1000 --- train_loss : [0.000704759156378798]
# training at iteration : 808/1000 --- train_loss : [0.000704750650287288]
# training at iteration : 809/1000 --- train_loss : [0.0007047421521346948]
# training at iteration : 810/1000 --- train_loss : [0.0007047336828190834]
# training at iteration : 811/1000 --- train_loss : [0.0007047252337523825]
# training at iteration : 812/1000 --- train_loss : [0.0007047168088940291]
# training at iteration : 813/1000 --- train_loss : [0.0007047083721301563]
# training at iteration : 814/1000 --- train_loss : [0.0007046999426695576]
# training at iteration : 815/1000 --- train_loss : [0.0007046915482699161]
# training at iteration : 816/1000 --- train_loss : [0.0007046831652541549]
# training at iteration : 817/1000 --- train_loss : [0.0007046747737307023]
# training at iteration : 818/1000 --- train_loss : [0.0007046664003281495]
# training at iteration : 819/1000 --- train_loss : [0.0007046580675026923]
# training at iteration : 820/1000 --- train_loss : [0.0007046497304499676]
# training at iteration : 821/1000 --- train_loss : [0.0007046413965318243]
# training at iteration : 822/1000 --- train_loss : [0.0007046330838586731]
# training at iteration : 823/1000 --- train_loss : [0.0007046248002356317]
# training at iteration : 824/1000 --- train_loss : [0.0007046164811570372]
# training at iteration : 825/1000 --- train_loss : [0.0007046081864087555]
# training at iteration : 826/1000 --- train_loss : [0.0007045999216553407]
# training at iteration : 827/1000 --- train_loss : [0.0007045916779729171]
# training at iteration : 828/1000 --- train_loss : [0.0007045834241118732]
# training at iteration : 829/1000 --- train_loss : [0.0007045751842621367]
# training at iteration : 830/1000 --- train_loss : [0.0007045669572749438]
# training at iteration : 831/1000 --- train_loss : [0.0007045587415236014]
# training at iteration : 832/1000 --- train_loss : [0.0007045505317235656]
# training at iteration : 833/1000 --- train_loss : [0.0007045423348755897]
# training at iteration : 834/1000 --- train_loss : [0.0007045341379070243]
# training at iteration : 835/1000 --- train_loss : [0.0007045259980065693]
# training at iteration : 836/1000 --- train_loss : [0.0007045178306111752]
# training at iteration : 837/1000 --- train_loss : [0.0007045096827138004]
# training at iteration : 838/1000 --- train_loss : [0.0007045015425331245]
# training at iteration : 839/1000 --- train_loss : [0.0007044934282203317]
# training at iteration : 840/1000 --- train_loss : [0.0007044853114985654]
# training at iteration : 841/1000 --- train_loss : [0.0007044772330237704]
# training at iteration : 842/1000 --- train_loss : [0.0007044691403872656]
# training at iteration : 843/1000 --- train_loss : [0.0007044610420593153]
# training at iteration : 844/1000 --- train_loss : [0.0007044529730754931]
# training at iteration : 845/1000 --- train_loss : [0.0007044449468820268]
# training at iteration : 846/1000 --- train_loss : [0.0007044369063248764]
# training at iteration : 847/1000 --- train_loss : [0.0007044288812348635]
# training at iteration : 848/1000 --- train_loss : [0.000704420878781834]
# training at iteration : 849/1000 --- train_loss : [0.000704412824415497]
# training at iteration : 993/1000 --- train_loss : [0.0007033630259447886]
# training at iteration : 994/1000 --- train_loss : [0.000703356340704045]
# training at iteration : 995/1000 --- train_loss : [0.000703349677244387]
# training at iteration : 996/1000 --- train_loss : [0.0007033430264101673]
# training at iteration : 997/1000 --- train_loss : [0.0007033363815571829]
# training at iteration : 998/1000 --- train_loss : [0.0007033297456240626]
# training at iteration : 999/1000 --- train_loss : [0.000703323107985323]
# training at iteration : 1000/1000 --- train_loss : [0.0007033164951108198]

# %%
pred = LSTM_forecast(test,model,scaler)
pred

# %%
y_hat = scale_prediction(scaler, data, pred)
np.sqrt(mean_squared_error(data['y_test'], y_hat))

# %%
np.sqrt(mean_squared_error(scaled_data['y_test'],pred))

# %% [markdown]
# # Process Flow
# ## 1. Data Preparation
# ## 2. Model trainning
# ## 3. Model evaluation
# ## 4. Saving Model and metadata
# ## 5. Load Model

# %%
'''data configuration'''

forecast = 7 #num of days to forecast
lag = 15 #num of days lagged back (as input features)
ft_cols = ['Estimated_fire_area','Mean_estimated_fire_brightness','Mean_estimated_fire_radiative_power'] #at least Estimated_fire_area should be included(univariate)
split = 0.8 #train ratio
states = ['NSW'] #selected region


'''model configuration'''

opt_params = { #optimizer params
    'lr' : 0.05, 
    'beta_1' : 0.9,
    'beta_2' : 0.999,
    'decay' : 0.005
} 
model_params = {
    'n_batch' : 1, #should be divisibled to the trainning size (just fix it to one in this case)
    'nb_epoch' : 100, #num of trainning iterations
    'n_neurons' : 25, #hidden units for each LSTM layer
    'opt_params' : opt_params
}

# %% [markdown]
# ## Data preparation

# %%
df1['Date'] = pd.to_datetime(df1['Date']) #df1 = estimated fire area dataFrame
df1_temp = df1.copy()
df1_temp = df1_temp[df1_temp['Region'].isin(states)]
df1_temp.reset_index(inplace = True)

df2['Date'] = pd.to_datetime(df2['Date'])
df2_temp = df2.copy()
df2_temp = df2_temp[df2_temp['Region'].isin(states)]
df2_temp.reset_index(inplace = True)

df = pd.merge(df1_temp, df2_temp, how='inner', on=['Date','Region']).drop('index_x', axis = 1)
scaler, data, scaled_data, train, test = prepared_data(df, forecast=forecast, lag=lag, ft_cols = ft_cols)

# %%
print(data['X_train'].shape)
print(data['y_train'].shape)
print(data['X_test'].shape)
print(data['y_test'].shape)
# Out:
# (3677, 45)
# (3677, 7)
# (904, 45)
# (904, 7)

# %% [markdown]
# ## Run and evaluate the model

# %%
model, log = LSTM_model(scaled_data, **model_params) #pass in the scaled trainning data
# Out:
# training at iteration : 1/100 --- train_loss : [0.0008845313575205231]
# training at iteration : 2/100 --- train_loss : [0.0007843713499609886]
# training at iteration : 3/100 --- train_loss : [0.0008453235367685092]
# training at iteration : 4/100 --- train_loss : [0.0009055911253691902]
# training at iteration : 5/100 --- train_loss : [0.0008292093541898411]
# training at iteration : 6/100 --- train_loss : [0.0007937709494349165]
# training at iteration : 7/100 --- train_loss : [0.0007782495414239744]
# training at iteration : 8/100 --- train_loss : [0.0007667858946804244]
# training at iteration : 58/100 --- train_loss : [0.0007156822622114518]
# training at iteration : 59/100 --- train_loss : [0.0007154816440665272]
# training at iteration : 60/100 --- train_loss : [0.0007152857036335871]
# training at iteration : 61/100 --- train_loss : [0.0007150941663203169]
# training at iteration : 62/100 --- train_loss : [0.0007149069449067436]
# training at iteration : 63/100 --- train_loss : [0.0007147238474821265]
# training at iteration : 64/100 --- train_loss : [0.0007145447197321043]
# training at iteration : 65/100 --- train_loss : [0.0007143693514037541]
# training at iteration : 66/100 --- train_loss : [0.0007141976628051998]
# training at iteration : 67/100 --- train_loss : [0.0007140295145678953]
# training at iteration : 68/100 --- train_loss : [0.0007138647565567616]
# training at iteration : 69/100 --- train_loss : [0.0007137032682836776]
# training at iteration : 70/100 --- train_loss : [0.0007135449388142979]
# training at iteration : 71/100 --- train_loss : [0.0007133896341156281]
# training at iteration : 72/100 --- train_loss : [0.0007132372240489509]
# training at iteration : 73/100 --- train_loss : [0.0007130877028035453]
# training at iteration : 74/100 --- train_loss : [0.0007129409032016336]
# training at iteration : 75/100 --- train_loss : [0.0007127967685605414]
# training at iteration : 76/100 --- train_loss : [0.0007126551542598515]
# training at iteration : 77/100 --- train_loss : [0.0007125159824133979]
# training at iteration : 78/100 --- train_loss : [0.0007123792413604417]
# training at iteration : 79/100 --- train_loss : [0.0007122447583937797]
# training at iteration : 80/100 --- train_loss : [0.0007121125440242655]
# training at iteration : 81/100 --- train_loss : [0.0007119824533694952]
# training at iteration : 82/100 --- train_loss : [0.0007118544460500188]
# training at iteration : 83/100 --- train_loss : [0.0007117284930471859]
# training at iteration : 84/100 --- train_loss : [0.0007116044957567878]
# training at iteration : 85/100 --- train_loss : [0.0007114823890750073]
# training at iteration : 86/100 --- train_loss : [0.0007113621378374573]
# training at iteration : 87/100 --- train_loss : [0.000711243699753778]
# training at iteration : 88/100 --- train_loss : [0.000711126935518018]
# training at iteration : 89/100 --- train_loss : [0.0007110119177415615]
# training at iteration : 90/100 --- train_loss : [0.000710898504641339]
# training at iteration : 91/100 --- train_loss : [0.0007107866506666181]
# training at iteration : 92/100 --- train_loss : [0.0007106763777447359]
# training at iteration : 93/100 --- train_loss : [0.0007105675665992779]
# training at iteration : 94/100 --- train_loss : [0.0007104602286356896]
# training at iteration : 95/100 --- train_loss : [0.000710354291779484]
# training at iteration : 96/100 --- train_loss : [0.0007102497446414476]
# training at iteration : 97/100 --- train_loss : [0.0007101465578080717]
# training at iteration : 98/100 --- train_loss : [0.0007100446321337667]
# training at iteration : 99/100 --- train_loss : [0.0007099440352659115]
# training at iteration : 100/100 --- train_loss : [0.0007098445896954482]

# %%
#plotting loss

plt.figure(figsize=(10, 6))
sns.set(style='whitegrid')
_log = [[i+1,log[i]] for i in range(len(log))]
log_df = pd.DataFrame(_log, columns = ['Iteration','loss'])
g = sns.lineplot(x='Iteration', y='loss', data=log_df)

# %%
#evaluating model
train_pred = LSTM_forecast(train, model, scaler, n_batch = 1, lag=lag, forecast=forecast, ft_cols = ft_cols)
rescaled_train_pred = inverse_pred(scaler, train_pred)
test_pred = LSTM_forecast(test, model, scaler, n_batch = 1, lag=lag, forecast=forecast, ft_cols = ft_cols)
rescaled_test_pred = inverse_pred(scaler, test_pred)

scaled_train_error = mean_squared_error(scaled_data['y_train'], train_pred)
raw_train_error = mean_squared_error(data['y_train'], rescaled_train_pred)
scaled_test_error = mean_squared_error(scaled_data['y_test'], test_pred)
raw_test_error = mean_squared_error(data['y_test'], rescaled_test_pred)

matrices = [[scaled_train_error,np.sqrt(scaled_train_error)],
           [raw_train_error,np.sqrt(raw_train_error)],
           [scaled_test_error,np.sqrt(scaled_test_error)],
           [raw_test_error,np.sqrt(raw_test_error)]]

res_df = pd.DataFrame(matrices, columns = ['MSE','RMSE'], index = ['train scaled error',
                                                                   'train error',
                                                                   'test scaled error',
                                                                   'test error'])
res_df
# Out:
#                               MSE        RMSE
# train scaled error       0.000709    0.026619
# train error           2994.903374   54.725710
# test scaled error        0.039274    0.198178
# test error          165997.968856  407.428483

# %% [markdown]
# ## Saving Model with metadata
#
# ### List of metadata
# 1. feature lists
# 2. scaler params including scaler.min_ and scaler.scale_
# 3. model configuration
# 4. data configuration

# %%
model_name = 'model1'
path = './model'
model.save(f'''{path}/{model_name}''')

# %%
'''
List of metadata
1. data configuration
2. model configuration
3. scaler params including scaler.min_ and scaler.scale_
'''

data_config = {
    'feature_list' : ft_cols,
    'states' : states,
    'forecast' : forecast,
    'lag' : lag,
    'split' : split
}

model_config = model_params

scaler_config = {
    'min_' : scaler.min_,
    'scale_' : scaler.scale_
}

meta = {
    'data_config' : [data_config],
    'model_config' : [model_config],
    'sclaer_config' : [scaler_config]
}

meta_df = pd.DataFrame(meta)
meta_df.to_csv(f'{path}/{model_name}_metadata', index=False)

# %% [markdown]
# ## Loading back the model and try prediction

# %%
load_model = keras.models.load_model('my_model')

# %%
#evaluating model
train_pred = LSTM_forecast(train, load_model, scaler, n_batch = 1, lag=lag, forecast=forecast, ft_cols = ft_cols)
rescaled_train_pred = inverse_pred(scaler, train_pred)
test_pred = LSTM_forecast(test, load_model, scaler, n_batch = 1, lag=lag, forecast=forecast, ft_cols = ft_cols)
rescaled_test_pred = inverse_pred(scaler, test_pred)

scaled_train_error = mean_squared_error(scaled_data['y_train'], train_pred)
raw_train_error = mean_squared_error(data['y_train'], rescaled_train_pred)
scaled_test_error = mean_squared_error(scaled_data['y_test'], test_pred)
raw_test_error = mean_squared_error(data['y_test'], rescaled_test_pred)

matrices = [[scaled_train_error,np.sqrt(scaled_train_error)],
           [raw_train_error,np.sqrt(raw_train_error)],
           [scaled_test_error,np.sqrt(scaled_test_error)],
           [raw_test_error,np.sqrt(raw_test_error)]]

res_df = pd.DataFrame(matrices, columns = ['MSE','RMSE'], index = ['train scaled error',
                                                                   'train error',
                                                                   'test scaled error',
                                                                   'test error'])
res_df
# Out:
#                               MSE        RMSE
# train scaled error       0.000710    0.026645
# train error           3000.663786   54.778315
# test scaled error        0.039274    0.198177
# test error          165997.693829  407.428146
